# %% [markdown]
# ## Sources and Credits
# This MLP model is based on Andrew Trask's Sentiment Analysis course on Udacity and the course materials he provided.

# %% [markdown]
# ## Load Data

# %%
g = open('mlptext.txt', 'r') #inputs
texts = list(map(lambda x:x[:-1].lower(),g.readlines()))
g.close()
g = open('mlptype.txt','r') #labels
types = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# ## Tokenizing

# %%
from nltk.tokenize import TweetTokenizer
from string import punctuation

tknzr = TweetTokenizer()
quotes = []
for text in texts:
    tokens = tknzr.tokenize(text)
    quotes.append(' '.join([token for token in tokens if token not in punctuation])) 
texts = quotes

# %%
print("TYPE \t: TEXT")
for i in range(5):
    print(types[i] + "\t: " + texts[i])
# Out:
# TYPE 	: TEXT
# MUNDANE	: the extensive literature addressed to the definition or characterization of science is filled with inconsistent points of view and demonstrates that an adequate definition is not easy to attain part of the difficulty arises from the fact that the meaning of science is not fixed but is dynamic as science has evolved so has its meaning it takes on a new meaning and significance with successive ages
# VACUOUS	: even if you don't have all the things you want be grateful for the things you don't have that you don't want
# VACUOUS	: you have to find the courage to live as you need to there will always be those who want you to be ordinary those who expect you to settle down your body can settle but you have to let your mind soar you have to hold onto the courage of your artistic convictions
# VACUOUS	: a mother gives you a life a mother-in-law gives you her life
# MUNDANE	: james shaw jr the man who wrested a rifle away from the waffle house gunman got emotional on tuesday when he received a standing ovation from the tennessee general assembly which officially recognized his heroism

# %% [markdown]
# ## Stemming (optional)

# %%
from nltk.stem import SnowballStemmer

snowball = SnowballStemmer(language='english')
quotes = []
for text in texts:
    quote = []
    for token in text.split(' '):
        stem = snowball.stem(token)
        quote.append(stem)
    quotes.append(' '.join(quote))
texts= quotes

# %%
print("TYPE \t: TEXT")
for i in range(5):
    print(types[i] + "\t: " + texts[i])
# Out:
# TYPE 	: TEXT
# MUNDANE	: the extens literatur address to the definit or character of scienc is fill with inconsist point of view and demonstr that an adequ definit is not easi to attain part of the difficulti aris from the fact that the mean of scienc is not fix but is dynam as scienc has evolv so has it mean it take on a new mean and signific with success age
# VACUOUS	: even if you don't have all the thing you want be grate for the thing you don't have that you don't want
# VACUOUS	: you have to find the courag to live as you need to there will alway be those who want you to be ordinari those who expect you to settl down your bodi can settl but you have to let your mind soar you have to hold onto the courag of your artist convict
# VACUOUS	: a mother give you a life a mother-in-law give you her life
# MUNDANE	: jame shaw jr the man who wrest a rifl away from the waffl hous gunman got emot on tuesday when he receiv a stand ovat from the tennesse general assembl which offici recogn his heroism

# %% [markdown]
# ## Lemmatizing (optional)

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
wnl = WordNetLemmatizer()

quotes = []
for text in texts:
    quote = []
    for word, tag in pos_tag(word_tokenize(text)):
        wntag = tag[0].lower()
        wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
        if not wntag:
            lemma = word
        else:
            lemma = wnl.lemmatize(word, wntag)
        quote.append(lemma)
    quotes.append(' '.join(quote))    
texts = quotes

# %%
print("TYPE \t: TEXT")
for i in range(5):
    print(types[i] + "\t: " + texts[i])
# Out:
# TYPE 	: TEXT
# MUNDANE	: the extens literatur address to the definit or character of scienc be fill with inconsist point of view and demonstr that an adequ definit be not easi to attain part of the difficulti aris from the fact that the mean of scienc be not fix but be dynam as scienc have evolv so have it mean it take on a new mean and signific with success age
# VACUOUS	: even if you do n't have all the thing you want be grate for the thing you do n't have that you do n't want
# VACUOUS	: you have to find the courag to live as you need to there will alway be those who want you to be ordinari those who expect you to settl down your bodi can settl but you have to let your mind soar you have to hold onto the courag of your artist convict
# VACUOUS	: a mother give you a life a mother-in-law give you her life
# MUNDANE	: jame shaw jr the man who wrest a rifl away from the waffl hous gunman get emot on tuesday when he receiv a stand ovat from the tennesse general assembl which offici recogn his heroism

# %% [markdown]
# ## Inspect the data
# can be skipped except ploting t-SNE in the end

# %%
from collections import Counter
import numpy as np

mundane_counts = Counter()
vacuous_counts = Counter()
total_counts = Counter()

for i in range(len(texts)):
    if(types[i] == 'MUNDANE'):
        for word in texts[i].split(" "):
            mundane_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in texts[i].split(" "):
            vacuous_counts[word] += 1
            total_counts[word] += 1

# %%
mundane_counts.most_common() #non-pseudo-profound
# Out:
# [('the', 27220),
#  ('of', 15302),
#  ('to', 11660),
#  ('and', 11343),
#  ('a', 11322),
#  ('in', 10615),
#  ('is', 6906),
#  ('that', 5267),
#  ('it', 4133),
#  ('on', 3742),
#  ('for', 3549),
#  ('as', 3095),
#  ('are', 2837),
#  ('with', 2534),
#  ('be', 2530),
#  ('was', 2448),
#  ('at', 2432),
#  ('we', 2314),
#  ('i', 2250),
#  ('not', 2213),
#  ('this', 2182),
#  ('by', 2116),
#  ('have', 2057),
#  ('you', 2057),
#  ('from', 2045),
#  ('but', 1905),
#  ('an', 1739),
#  ('has', 1635),
#  ('they', 1596),
#  ('or', 1582),
#  ('science', 1499),
#  ('he', 1468),
#  ('all', 1462),
#  ('one', 1446),
#  ('his', 1429),
#  ('which', 1388),
#  ('their', 1322),
#  ('people', 1307),
#  ('will', 1278),
#  ('who', 1244),
#  ('more', 1220),
#  ('our', 1181),
#  ('what', 1128),
#  ('there', 1099),
#  ('can', 1096),
#  ('if', 1092),
#  ('no', 1036),
#  ('were', 1016),
#  ('when', 1013),
#  ('than', 1012),
#  ('world', 973),
#  ('its', 952),
#  ('us', 946),
#  ('new', 908),
#  ('been', 908),
#  ('so', 886),
#  ('about', 883),
#  ('after', 838),
#  ('”', 837),
#  ('time', 798),
#  ('first', 775),
#  ('into', 766),
#  ('do', 766),
#  ('would', 746),
#  ('them', 743),
#  ('only', 739),
#  ('out', 737),
#  ('said', 736),
#  ('her', 727),
#  ('up', 722),
#  ('like', 709),
#  ('life', 662),
#  ('had', 657),
#  ('my', 649),
#  ('just', 639),
#  ('some', 621),
#  ('over', 616),
#  ('most', 613),
#  ('how', 608),
#  ('other', 599),
#  ("it's", 598),
#  ('president', 593),
#  ('years', 591),
#  ('human', 585),
#  ('...', 574),
#  ('your', 560),
#  ('man', 554),
#  ('—', 546),
#  ('she', 540),
#  ('because', 534),
#  ('know', 512),
#  ('two', 489),
#  ('these', 486),
#  ('day', 480),
#  ('during', 480),
#  ('even', 480),
#  ('any', 480),
#  ('could', 475),
#  ('many', 469),
#  ('now', 463),
#  ('way', 460),
#  ('being', 452),
#  ('may', 452),
#  ('where', 449),
#  ('through', 441),
#  ('year', 431),
#  ('made', 431),
#  ('every', 431),
#  ('make', 428),
#  ('me', 419),
#  ('those', 413),
#  ('universe', 412),
#  ('then', 411),
#  ('think', 410),
#  ('trump', 382),
#  ('also', 381),
#  ('things', 381),
#  ('see', 379),
#  ('before', 375),
#  ('scientific', 373),
#  ('very', 365),
#  ('must', 361),
#  ('say', 354),
#  ('him', 353),
#  ('power', 353),
#  ('’', 349),
#  ('without', 347),
#  ('city', 344),
#  ('last', 342),
#  ('god', 342),
#  ('should', 339),
#  ('between', 335),
#  ('much', 333),
#  ('history', 329),
#  ('never', 329),
#  ("don't", 326),
#  ('nature', 323),
#  ('while', 323),
#  ('such', 314),
#  ('s', 312),
#  ('since', 309),
#  ('today', 308),
#  ('own', 306),
#  ('part', 302),
#  ('work', 299),
#  ('nothing', 296),
#  ('still', 295),
#  ('get', 294),
#  ('great', 293),
#  ('believe', 292),
#  ('something', 289),
#  ('men', 285),
#  ('down', 285),
#  ('knowledge', 279),
#  ('good', 276),
#  ('same', 274),
#  ('around', 274),
#  ('off', 273),
#  ('take', 271),
#  ('against', 269),
#  ('tuesday', 267),
#  ('least', 267),
#  ('back', 265),
#  ('cannot', 263),
#  ('become', 261),
#  ('always', 260),
#  ('“', 260),
#  ('here', 259),
#  ('ever', 251),
#  ('want', 251),
#  ('each', 250),
#  ('earth', 249),
#  ('well', 249),
#  ('place', 247),
#  ('left', 246),
#  ('three', 244),
#  ('mind', 244),
#  ('why', 242),
#  ('police', 242),
#  ('too', 240),
#  ('long', 240),
#  ('women', 239),
#  ('does', 239),
#  ('truth', 239),
#  ('according', 238),
#  ('right', 236),
#  ('space', 234),
#  ('called', 233),
#  ('state', 233),
#  ('white', 232),
#  ('religion', 231),
#  ('another', 230),
#  ('thought', 228),
#  ('week', 228),
#  ('country', 227),
#  ('come', 227),
#  ('across', 227),
#  ('far', 226),
#  ('national', 225),
#  ('little', 225),
#  ('thing', 225),
#  ('house', 224),
#  ('says', 224),
#  ('really', 223),
#  ('children', 223),
#  ('scientists', 221),
#  ('thursday', 220),
#  ('find', 219),
#  ('south', 219),
#  ('school', 219),
#  ('both', 218),
#  ('past', 218),
#  ('night', 216),
#  ('water', 216),
#  ('go', 216),
#  ('killed', 215),
#  ('took', 214),
#  ('am', 213),
#  ('best', 212),
#  ('technology', 212),
#  ('fact', 210),
#  ('north', 210),
#  ('look', 209),
#  ('known', 208),
#  ('end', 208),
#  ('love', 208),
#  ('true', 208),
#  ('sunday', 205),
#  ('fire', 205),
#  ('monday', 204),
#  ('york', 201),
#  ('everything', 200),
#  ('different', 198),
#  ('died', 198),
#  ('live', 198),
#  ('did', 197),
#  ('reason', 196),
#  ('itself', 196),
#  ('change', 195),
#  ('sense', 194),
#  ('war', 194),
#  ('thousands', 194),
#  ('wednesday', 192),
#  ('might', 192),
#  ('others', 192),
#  ("that's", 192),
#  ('shows', 191),
#  ('means', 190),
#  ('better', 190),
#  ('yet', 189),
#  ('former', 186),
#  ('need', 185),
#  ('real', 185),
#  ('understand', 185),
#  ('outside', 183),
#  ('friday', 181),
#  ('moment', 181),
#  ('few', 180),
#  ('important', 179),
#  ('system', 179),
#  ('art', 178),
#  ('going', 178),
#  ('help', 176),
#  ('donald', 175),
#  ('once', 174),
#  ('high', 173),
#  ('use', 172),
#  ('matter', 172),
#  ('.', 172),
#  ('home', 171),
#  ('natural', 171),
#  ('used', 171),
#  ('family', 170),
#  ('society', 170),
#  ('big', 170),
#  ('less', 169),
#  ('london', 169),
#  ('set', 169),
#  ('together', 167),
#  ('days', 167),
#  ('possible', 166),
#  ('light', 166),
#  ('old', 165),
#  ('black', 164),
#  ('show', 163),
#  ('million', 163),
#  ('near', 162),
#  ('question', 162),
#  ('anything', 161),
#  ('photo', 161),
#  ('year-old', 160),
#  ('often', 160),
#  ('ago', 160),
#  ('living', 159),
#  ('lives', 159),
#  ('future', 159),
#  ('seen', 159),
#  ('person', 158),
#  ('give', 158),
#  ('evolution', 158),
#  ('…', 158),
#  ('found', 158),
#  ('enough', 157),
#  ('woman', 156),
#  ('race', 156),
#  ('order', 155),
#  ('under', 155),
#  ('florida', 155),
#  ("i'm", 154),
#  ('social', 154),
#  ('language', 154),
#  ('death', 154),
#  ('away', 153),
#  ('reality', 153),
#  ('almost', 153),
#  ('prince', 151),
#  ('next', 150),
#  ('view', 149),
#  ('political', 149),
#  ('whole', 149),
#  ('obama', 148),
#  ('video', 148),
#  ('group', 147),
#  ('age', 147),
#  ('public', 146),
#  ('government', 146),
#  ('young', 146),
#  ('point', 146),
#  ('four', 145),
#  ('morning', 144),
#  ('storm', 144),
#  ('california', 143),
#  ('festival', 143),
#  ('among', 142),
#  ('whether', 142),
#  ('american', 141),
#  ('united', 141),
#  ('again', 140),
#  ('modern', 140),
#  ('laws', 140),
#  ('free', 139),
#  ('themselves', 139),
#  ('times', 139),
#  ('rather', 139),
#  ("can't", 139),
#  ('theory', 139),
#  ('kind', 138),
#  ('thinking', 137),
#  ('until', 137),
#  ('states', 137),
#  ('upon', 136),
#  ('came', 135),
#  ('including', 134),
#  ('above', 133),
#  ('building', 132),
#  ('attack', 132),
#  ('air', 132),
#  ('physics', 131),
#  ('put', 131),
#  ('hurricane', 131),
#  ('park', 131),
#  ('religious', 129),
#  ('event', 129),
#  ('scientist', 129),
#  ('face', 129),
#  ('feel', 129),
#  ('makes', 129),
#  ('words', 128),
#  ('education', 128),
#  ('saturday', 128),
#  ('moon', 128),
#  ('idea', 128),
#  ('small', 127),
#  ('philosophy', 127),
#  ('tell', 127),
#  ('evidence', 126),
#  ('nearly', 125),
#  ('created', 125),
#  ('party', 125),
#  ('later', 125),
#  ('got', 124),
#  ('intelligence', 124),
#  ('2016', 124),
#  ('else', 123),
#  ('became', 122),
#  ('members', 122),
#  ('shooting', 121),
#  ('protesters', 120),
#  ('full', 120),
#  ('within', 120),
#  ('able', 120),
#  ('form', 120),
#  ('stars', 119),
#  ('students', 119),
#  ('washington', 119),
#  ("doesn't", 119),
#  ('military', 118),
#  ('early', 118),
#  ('experience', 118),
#  ('along', 117),
#  ('brain', 116),
#  ('hope', 116),
#  ('residents', 116),
#  ('understanding', 115),
#  ('making', 115),
#  ('dead', 115),
#  ('course', 114),
#  ('taken', 114),
#  ('wrong', 114),
#  ('simply', 114),
#  ('century', 112),
#  ('number', 112),
#  ('protest', 112),
#  ('snow', 112),
#  ('questions', 112),
#  ('behind', 111),
#  ('memory', 111),
#  ('international', 111),
#  ('china', 111),
#  ('second', 110),
#  ('faith', 110),
#  ('given', 110),
#  ('business', 110),
#  ('february', 110),
#  ('however', 110),
#  ('support', 110),
#  ('month', 110),
#  ('island', 110),
#  ('body', 109),
#  ('existence', 109),
#  ('ice', 109),
#  ('area', 109),
#  ('community', 109),
#  ('child', 108),
#  ('five', 108),
#  ('physical', 108),
#  ('progress', 108),
#  ('present', 108),
#  ('ideas', 108),
#  ('species', 107),
#  ('comes', 107),
#  ("we're", 107),
#  ('though', 107),
#  ('streets', 106),
#  ('research', 106),
#  ("you're", 106),
#  ('rights', 106),
#  ('facts', 106),
#  ('‘', 106),
#  ('energy', 106),
#  ('general', 105),
#  ('already', 105),
#  ('actually', 105),
#  ('–', 105),
#  ('politics', 105),
#  ('call', 105),
#  ('march', 105),
#  ('minister', 105),
#  ('let', 105),
#  ('hand', 104),
#  ('large', 104),
#  ('told', 103),
#  ('culture', 103),
#  ('information', 103),
#  ('lost', 103),
#  ('simple', 103),
#  ('korea', 103),
#  ('town', 102),
#  ('leader', 102),
#  ('belief', 102),
#  ('learn', 102),
#  ('someone', 102),
#  ('hard', 102),
#  ('held', 102),
#  ('quite', 102),
#  ('open', 102),
#  ('perhaps', 102),
#  ('visit', 101),
#  ('ceremony', 101),
#  ('seems', 101),
#  ('ourselves', 101),
#  ('annual', 101),
#  ('center', 101),
#  ('expected', 101),
#  ('korean', 100),
#  ("there's", 100),
#  ('victims', 100),
#  ('himself', 100),
#  ('sun', 100),
#  ('keep', 100),
#  ('single', 99),
#  ('book', 99),
#  ('control', 99),
#  ("didn't", 99),
#  ('process', 98),
#  ('try', 98),
#  ('common', 98),
#  ('sometimes', 98),
#  ('heart', 98),
#  ('humans', 98),
#  ('problem', 98),
#  ('beyond', 98),
#  ('sky', 98),
#  ('went', 98),
#  ('turned', 97),
#  ('england', 97),
#  ('america', 97),
#  ('service', 97),
#  ('hundreds', 97),
#  ('street', 97),
#  ('began', 96),
#  ('word', 96),
#  ('british', 96),
#  ('hit', 96),
#  ('northern', 96),
#  ('prime', 96),
#  ('red', 95),
#  ('lot', 95),
#  ('team', 95),
#  ('answer', 95),
#  ('start', 95),
#  ('name', 95),
#  ('beach', 95),
#  ('india', 95),
#  ('whose', 94),
#  ('asked', 94),
#  ('problems', 94),
#  ('planet', 94),
#  ('line', 94),
#  ('result', 94),
#  ('several', 94),
#  ('sea', 94),
#  ('force', 94),
#  ('certain', 94),
#  ('court', 93),
#  ('10', 93),
#  ('inside', 93),
#  ('story', 93),
#  ('law', 93),
#  ('turn', 93),
#  ('instead', 93),
#  ('officials', 93),
#  ('mother', 93),
#  ('father', 93),
#  ('brought', 93),
#  ('ahead', 92),
#  ('done', 92),
#  ('doing', 91),
#  ('media', 91),
#  ('photographer', 91),
#  ('care', 91),
#  ('feet', 91),
#  ('beings', 90),
#  ('official', 90),
#  ('hours', 90),
#  ('following', 89),
#  ('study', 89),
#  ('working', 89),
#  ('parts', 89),
#  ('takes', 88),
#  ('border', 88),
#  ('peace', 88),
#  ('bring', 88),
#  ('u', 88),
#  ('captured', 88),
#  ('late', 88),
#  ('2017', 88),
#  ('nor', 88),
#  ('based', 87),
#  ('economic', 87),
#  ('stop', 87),
#  ('fear', 87),
#  ('homes', 87),
#  ('born', 87),
#  ("they're", 86),
#  ('largest', 86),
#  ('field', 86),
#  ('read', 86),
#  ('mean', 86),
#  ('everyone', 86),
#  ('either', 86),
#  ('massive', 86),
#  ('rain', 86),
#  ('chinese', 86),
#  ('texas', 85),
#  ('food', 85),
#  ('star', 85),
#  ('side', 85),
#  ("world's", 85),
#  ('front', 85),
#  ('months', 85),
#  ('central', 85),
#  ('christmas', 85),
#  ('series', 84),
#  ('design', 84),
#  ("isn't", 84),
#  ('freedom', 84),
#  ('money', 84),
#  ('coast', 84),
#  ('therefore', 84),
#  ('forces', 84),
#  ('taking', 84),
#  ('french', 84),
#  ("trump's", 83),
#  ('sure', 83),
#  ('trying', 83),
#  ('events', 83),
#  ('shot', 83),
#  ('works', 82),
#  ('election', 82),
#  ('looking', 82),
#  ('won', 81),
#  ('results', 81),
#  ('create', 81),
#  ('eyes', 81),
#  ('mass', 81),
#  ('greater', 81),
#  ('square', 81),
#  ('record', 81),
#  ('hold', 81),
#  ('caused', 81),
#  ('whatever', 81),
#  ('20', 81),
#  ('hands', 81),
#  ('act', 80),
#  ('exist', 80),
#  ('january', 80),
#  ('special', 80),
#  ('earlier', 79),
#  ('honor', 79),
#  ('sciences', 79),
#  ('countries', 79),
#  ('vote', 79),
#  ('final', 79),
#  ('paris', 79),
#  ('shall', 79),
#  ('st', 79),
#  ('beautiful', 78),
#  ('learned', 78),
#  ('major', 78),
#  ('dark', 78),
#  ('west', 78),
#  ('ask', 78),
#  ('image', 78),
#  ('leave', 77),
#  ('necessary', 77),
#  ('music', 77),
#  ('weeks', 77),
#  ('particular', 77),
#  ('speech', 77),
#  ('six', 77),
#  ('impossible', 77),
#  ('violence', 77),
#  ('injured', 77),
#  ('capital', 77),
#  ('presidential', 77),
#  ('winter', 77),
#  ('1', 77),
#  ('clear', 77),
#  ('deep', 77),
#  ('needs', 76),
#  ('spirit', 76),
#  ('rest', 76),
#  ('lady', 76),
#  ('animals', 76),
#  ('happy', 75),
#  ('miles', 75),
#  ('artist', 75),
#  ('15', 74),
#  ('queen', 74),
#  ('tower', 74),
#  ('de', 74),
#  ('millions', 74),
#  ('remain', 74),
#  ('saying', 74),
#  ('discovery', 74),
#  ('meaning', 73),
#  ('mark', 73),
#  ('popular', 73),
#  ('11', 73),
#  ('having', 73),
#  ('soon', 73),
#  ('beginning', 73),
#  ('complex', 73),
#  ('sex', 73),
#  ('continue', 73),
#  ('met', 72),
#  ('local', 72),
#  ('believed', 72),
#  ('church', 72),
#  ('powerful', 72),
#  ('personal', 72),
#  ('indeed', 72),
#  ('cause', 72),
#  ('travel', 72),
#  ('role', 72),
#  ('started', 72),
#  ('happened', 72),
#  ('looks', 72),
#  ('individual', 72),
#  ('buildings', 72),
#  ('alone', 72),
#  ('supreme', 71),
#  ('case', 71),
#  ('game', 71),
#  ('news', 71),
#  ('purpose', 71),
#  ('sexual', 71),
#  ('humanity', 71),
#  ('using', 71),
#  ('camp', 71),
#  ('office', 70),
#  ('remember', 70),
#  ('leaders', 70),
#  ('photos', 70),
#  ('strong', 70),
#  ('intelligent', 70),
#  ('evil', 70),
#  ('ignorance', 70),
#  ('stand', 70),
#  ('authorities', 70),
#  ('knows', 70),
#  ('seem', 70),
#  ('14', 70),
#  ('built', 70),
#  ('girl', 69),
#  ('announced', 69),
#  ('flight', 69),
#  ('100', 69),
#  ('destroyed', 69),
#  ('top', 69),
#  ('population', 69),
#  ('region', 68),
#  ('tree', 68),
#  ('friends', 68),
#  ('coming', 68),
#  ('justice', 68),
#  ('finally', 68),
#  ('global', 68),
#  ('rule', 68),
#  ('t', 68),
#  ('yourself', 68),
#  ('memorial', 68),
#  ('action', 68),
#  ('reach', 68),
#  ('fall', 68),
#  ('beauty', 68),
#  ('land', 68),
#  ('17', 68),
#  ('generation', 68),
#  ('duchess', 67),
#  ('color', 67),
#  ('due', 67),
#  ('ways', 67),
#  ('meet', 67),
#  ('released', 67),
#  ("he's", 67),
#  ('run', 67),
#  ('led', 67),
#  ('felt', 67),
#  ('2', 67),
#  ('schools', 67),
#  ('difficult', 67),
#  ('weather', 67),
#  ('campaign', 66),
#  ('female', 66),
#  ('conditions', 66),
#  ('king', 66),
#  ('lead', 66),
#  ('stage', 66),
#  ('recent', 66),
#  ('move', 66),
#  ('sign', 66),
#  ('12', 66),
#  ('heavy', 66),
#  ('systems', 66),
#  ('harry', 65),
#  ('river', 65),
#  ('gathered', 65),
#  ('boy', 65),
#  ('walk', 65),
#  ('japan', 65),
#  ('value', 65),
#  ('thousand', 65),
#  ('probably', 65),
#  ('merely', 65),
#  ('royal', 64),
#  ('southern', 64),
#  ('spring', 64),
#  ('longer', 64),
#  ('short', 64),
#  ('build', 64),
#  ('democratic', 64),
#  ('stands', 64),
#  ('celebrate', 64),
#  ('explain', 64),
#  ('birth', 64),
#  ('anniversary', 64),
#  ('john', 64),
#  ('lies', 64),
#  ('difference', 64),
#  ('minds', 64),
#  ('health', 64),
#  ('learning', 64),
#  ('knew', 64),
#  ('plane', 63),
#  ('tradition', 63),
#  ('development', 63),
#  ('2018', 63),
#  ('happen', 63),
#  ('opened', 63),
#  ('getting', 63),
#  ('goes', 63),
#  ('flooding', 63),
#  ('wonder', 63),
#  ('museum', 63),
#  ('cold', 63),
#  ('pay', 63),
#  ('kim', 62),
#  ('fight', 62),
#  ('europe', 62),
#  ('creation', 62),
#  ('nation', 62),
#  ('chance', 62),
#  ('climate', 62),
#  ('speak', 62),
#  ('terms', 62),
#  ('france', 62),
#  ('wisdom', 62),
#  ('bad', 62),
#  ('head', 62),
#  ('australia', 62),
#  ('station', 62),
#  ('security', 61),
#  ('anyone', 61),
#  ('blue', 61),
#  ('traditional', 61),
#  ('myself', 61),
#  ('although', 61),
#  ('toward', 61),
#  ('deal', 61),
#  ('clinton', 61),
#  ('discovered', 61),
#  ('ocean', 61),
#  ('weekend', 61),
#  ('volcano', 61),
#  ('room', 61),
#  ('africa', 61),
#  ('doubt', 61),
#  ('likely', 60),
#  ('imagine', 60),
#  ('temperatures', 60),
#  ('intellectual', 60),
#  ('moral', 60),
#  ('close', 60),
#  ('george', 60),
#  ('flowers', 60),
#  ("country's", 60),
#  ('follow', 60),
#  ('claim', 60),
#  ('carolina', 60),
#  ('famous', 60),
#  ('level', 60),
#  ('completely', 60),
#  ('capitol', 60),
#  ('lights', 60),
#  ('rare', 60),
#  ('dangerous', 60),
#  ('wall', 59),
#  ('books', 59),
#  ('structure', 59),
#  ('entire', 59),
#  ('dream', 59),
#  ('rational', 59),
#  ('serve', 59),
#  ('republican', 59),
#  ('written', 59),
#  ('watch', 59),
#  ('evening', 59),
#  ('subject', 59),
#  ('parents', 59),
#  ('sound', 59),
#  ('lake', 59),
#  ('answers', 59),
#  ('wrote', 59),
#  ('30', 59),
#  ('marks', 58),
#  ('feeling', 58),
#  ('june', 58),
#  ('becomes', 58),
#  ('4', 58),
#  ('example', 58),
#  ('civil', 58),
#  ('lived', 58),
#  ('false', 58),
#  ('car', 58),
#  ('disease', 58),
#  ('nations', 58),
#  ('trip', 58),
#  ('imagination', 58),
#  ('talk', 58),
#  ('third', 58),
#  ('dna', 58),
#  ('method', 58),
#  ('principle', 58),
#  ('easy', 57),
#  ('gave', 57),
#  ('ground', 57),
#  ('ancient', 57),
#  ('billion', 57),
#  ('meeting', 57),
#  ('uk', 57),
#  ('rules', 57),
#  ('neither', 57),
#  ('mystery', 57),
#  ('especially', 57),
#  ('computer', 57),
#  ('terror', 57),
#  ('half', 57),
#  ('decades', 57),
#  ('allow', 57),
#  ('mathematics', 56),
#  ('son', 56),
#  ('spiritual', 56),
#  ('hundred', 56),
#  ('universal', 56),
#  ('soul', 56),
#  ('rescue', 56),
#  ('effort', 56),
#  ('m', 56),
#  ('ones', 56),
#  ('hong', 56),
#  ('bush', 56),
#  ('birthday', 55),
#  ('saw', 55),
#  ('cover', 55),
#  ('environment', 55),
#  ('ability', 55),
#  ('search', 55),
#  ('rally', 55),
#  ('civilization', 55),
#  ('gives', 55),
#  ('trees', 55),
#  ('towards', 55),
#  ('greatest', 55),
#  ("man's", 55),
#  ('college', 55),
#  ('army', 55),
#  ('prove', 55),
#  ('rise', 55),
#  ('becoming', 55),
#  ('holds', 55),
#  ('emotional', 54),
#  ('april', 54),
#  ('numbers', 54),
#  ('thus', 54),
#  ('mexico', 54),
#  ('looked', 54),
#  ('virginia', 54),
#  ('complete', 54),
#  ('class', 54),
#  ("women's", 54),
#  ('consciousness', 54),
#  ('protests', 54),
#  ('wish', 54),
#  ('remains', 54),
#  ('baby', 53),
#  ('places', 53),
#  ('heard', 53),
#  ('east', 53),
#  ('families', 53),
#  ('key', 53),
#  ('unknown', 53),
#  ('experiment', 53),
#  ('western', 53),
#  ('basic', 53),
#  ('hillary', 53),
#  ('eye', 53),
#  ('germany', 53),
#  ('forms', 53),
#  ('discoveries', 53),
#  ('machine', 53),
#  ('position', 53),
#  ('cultural', 53),
#  ('wanted', 53),
#  ('discover', 53),
#  ('un', 52),
#  ('flag', 52),
#  ('biology', 52),
#  ('message', 52),
#  ('seemed', 52),
#  ('consider', 52),
#  ('protect', 52),
#  ('student', 52),
#  ('step', 52),
#  ('workers', 52),
#  ('season', 52),
#  ('winds', 52),
#  ('worst', 52),
#  ('statement', 52),
#  ...]

# %%
vacuous_counts.most_common() #pseudo-profound
# Out:
# [('the', 11901),
#  ('to', 8982),
#  ('you', 8666),
#  ('and', 7176),
#  ('of', 6057),
#  ('is', 5657),
#  ('a', 5507),
#  ('in', 4129),
#  ('that', 3758),
#  ('it', 3708),
#  ('your', 3607),
#  ('i', 3507),
#  ('be', 2779),
#  ('are', 2576),
#  ('we', 2359),
#  ('not', 2339),
#  ('for', 2271),
#  ('have', 1895),
#  ('life', 1862),
#  ('what', 1727),
#  ('with', 1714),
#  ('but', 1694),
#  ('will', 1551),
#  ('can', 1523),
#  ('if', 1495),
#  ('all', 1444),
#  ('as', 1314),
#  ('when', 1288),
#  ('do', 1279),
#  ('on', 1261),
#  ('or', 1238),
#  ('my', 1191),
#  ('love', 1145),
#  ('they', 1126),
#  ('who', 1057),
#  ('our', 1041),
#  ('one', 1021),
#  ('no', 985),
#  ("don't", 969),
#  ('there', 945),
#  ('me', 937),
#  ('this', 934),
#  ('people', 897),
#  ('never', 868),
#  ('from', 805),
#  ('world', 801),
#  ('so', 791),
#  ("it's", 786),
#  ('by', 781),
#  ('only', 779),
#  ('at', 774),
#  ('yourself', 771),
#  ('like', 749),
#  ('things', 732),
#  ('make', 721),
#  ('us', 719),
#  ('them', 682),
#  ('about', 668),
#  ('know', 667),
#  ('more', 667),
#  ('how', 659),
#  ('just', 655),
#  ('because', 648),
#  ('up', 647),
#  ('time', 641),
#  ('he', 629),
#  ('than', 622),
#  ('an', 619),
#  ('way', 609),
#  ('always', 607),
#  ('want', 597),
#  ('was', 584),
#  ('out', 569),
#  ('their', 560),
#  ('own', 523),
#  ('...', 516),
#  ('let', 502),
#  ('something', 491),
#  ('go', 490),
#  ('has', 488),
#  ('every', 481),
#  ('live', 477),
#  ('heart', 468),
#  ('see', 465),
#  ('get', 457),
#  ('into', 455),
#  ('think', 455),
#  ('good', 450),
#  ('day', 443),
#  ("you're", 435),
#  ('being', 432),
#  ('god', 430),
#  ('take', 430),
#  ('am', 414),
#  ('even', 413),
#  ('where', 412),
#  ('find', 407),
#  ('those', 396),
#  ('then', 385),
#  ('his', 383),
#  ('most', 373),
#  ('others', 370),
#  ('change', 364),
#  ('give', 361),
#  ('other', 361),
#  ('mind', 359),
#  ('thing', 355),
#  ('she', 355),
#  ('better', 354),
#  ('believe', 347),
#  ('right', 347),
#  ('which', 346),
#  ('come', 344),
#  ('nothing', 340),
#  ('may', 336),
#  ('everything', 334),
#  ('need', 330),
#  ('some', 330),
#  ('would', 330),
#  ('best', 328),
#  ('feel', 327),
#  ("i'm", 322),
#  ('must', 321),
#  ('person', 316),
#  ('much', 312),
#  ('man', 307),
#  ('now', 304),
#  ('been', 302),
#  ('her', 297),
#  ('through', 296),
#  ('say', 294),
#  ('its', 294),
#  ("can't", 293),
#  ('look', 293),
#  ('soul', 293),
#  ('were', 292),
#  ('each', 290),
#  ('dreams', 289),
#  ('someone', 288),
#  ('too', 284),
#  ('going', 283),
#  ('become', 280),
#  ('without', 276),
#  ('should', 276),
#  ('work', 272),
#  ('down', 266),
#  ('ever', 263),
#  ('any', 261),
#  ('had', 260),
#  ('new', 260),
#  ('true', 258),
#  ('could', 256),
#  ('keep', 255),
#  ('great', 254),
#  ('sometimes', 252),
#  ("that's", 251),
#  ('light', 245),
#  ('really', 242),
#  ('moment', 242),
#  ('does', 232),
#  ('beautiful', 230),
#  ('else', 229),
#  ('dream', 228),
#  ('still', 225),
#  ('why', 224),
#  ('back', 223),
#  ('before', 223),
#  ('him', 221),
#  ('little', 220),
#  ('happiness', 219),
#  ('learn', 218),
#  ('cannot', 218),
#  ('fear', 218),
#  ('matter', 216),
#  ('away', 215),
#  ('anything', 214),
#  ('makes', 213),
#  ('today', 211),
#  ('over', 209),
#  ('”', 209),
#  ('enough', 209),
#  ('“', 208),
#  ('end', 206),
#  ("doesn't", 202),
#  ('many', 200),
#  ('first', 199),
#  ('—', 199),
#  ('same', 198),
#  ('doing', 196),
#  ('power', 196),
#  ('here', 195),
#  ('stop', 195),
#  ('place', 194),
#  ('made', 190),
#  ('long', 189),
#  ('human', 187),
#  ('words', 184),
#  ('happy', 183),
#  ('beauty', 180),
#  ('again', 179),
#  ('lives', 178),
#  ('important', 178),
#  ('said', 176),
#  ('while', 175),
#  ('around', 174),
#  ('future', 174),
#  ('these', 173),
#  ('another', 173),
#  ('try', 171),
#  ('truth', 170),
#  ('once', 169),
#  ('living', 167),
#  ("there's", 166),
#  ('hope', 166),
#  ('tell', 166),
#  ('comes', 165),
#  ('kind', 164),
#  ('myself', 164),
#  ('peace', 162),
#  ('ourselves', 160),
#  ('after', 160),
#  ('success', 158),
#  ('eyes', 157),
#  ('within', 155),
#  ('past', 155),
#  ('choose', 155),
#  ('everyone', 155),
#  ('very', 154),
#  ('real', 152),
#  ("i've", 151),
#  ('remember', 151),
#  ('until', 150),
#  ('hard', 143),
#  ("you've", 143),
#  ('start', 142),
#  ('face', 140),
#  ('write', 138),
#  ('faith', 137),
#  ('smile', 135),
#  ("you'll", 135),
#  ('grow', 135),
#  ('stay', 134),
#  ('whatever', 134),
#  ('trying', 134),
#  ('thought', 133),
#  ('well', 133),
#  ('worth', 133),
#  ('create', 132),
#  ('different', 131),
#  ('two', 131),
#  ('yet', 131),
#  ('…', 131),
#  ('free', 130),
#  ('help', 130),
#  ('such', 128),
#  ('bad', 127),
#  ('means', 127),
#  ('joy', 126),
#  ('happen', 126),
#  ('anyone', 126),
#  ('between', 125),
#  ('greatest', 124),
#  ('strength', 124),
#  ('inspiration', 124),
#  ('part', 123),
#  ('courage', 122),
#  ('also', 122),
#  ('inside', 122),
#  ('reason', 122),
#  ('put', 122),
#  ('lose', 121),
#  ('done', 121),
#  ('walk', 120),
#  ('off', 119),
#  ('earth', 119),
#  ('step', 118),
#  ('self', 118),
#  ('stars', 117),
#  ('times', 117),
#  ('understand', 116),
#  ('hold', 115),
#  ('lost', 115),
#  ('last', 114),
#  ('might', 114),
#  ('experience', 114),
#  ('thoughts', 112),
#  ('did', 112),
#  ('found', 111),
#  ('days', 111),
#  ('move', 111),
#  ('stand', 111),
#  ('fall', 110),
#  ('less', 109),
#  ('men', 109),
#  ('rather', 109),
#  ('wrong', 108),
#  ('universe', 108),
#  ('able', 107),
#  ('making', 107),
#  ('pain', 107),
#  ('ask', 107),
#  ('open', 106),
#  ('path', 106),
#  ('die', 105),
#  ('ones', 105),
#  ('whole', 105),
#  ('leave', 104),
#  ('alone', 104),
#  ('choice', 103),
#  ('purpose', 103),
#  ('instead', 103),
#  ('turn', 103),
#  ('care', 103),
#  ('forward', 103),
#  ('takes', 102),
#  ("isn't", 102),
#  ('afraid', 102),
#  ('story', 102),
#  ('friends', 101),
#  ('small', 101),
#  ('big', 101),
#  ('bring', 101),
#  ('control', 101),
#  ('yours', 101),
#  ('journey', 101),
#  ('upon', 101),
#  ("we're", 100),
#  ('death', 100),
#  ('often', 100),
#  ('deep', 99),
#  ('forever', 99),
#  ('present', 99),
#  ('waiting', 99),
#  ('together', 99),
#  ('got', 99),
#  ('strong', 99),
#  ('loved', 98),
#  ('nature', 98),
#  ('begin', 97),
#  ('truly', 97),
#  ('perfect', 96),
#  ('positive', 96),
#  ('reality', 95),
#  ('accept', 95),
#  ('though', 95),
#  ('rest', 95),
#  ('forget', 94),
#  ('reach', 94),
#  ('freedom', 93),
#  ('mean', 93),
#  ('feeling', 93),
#  ('looking', 92),
#  ('wait', 92),
#  ('thinking', 92),
#  ('act', 92),
#  ('achieve', 92),
#  ('night', 92),
#  ('spirit', 91),
#  ('themselves', 91),
#  ('use', 91),
#  ('sky', 91),
#  ('darkness', 91),
#  ('body', 90),
#  ('having', 90),
#  ('focus', 90),
#  ('tomorrow', 90),
#  ('woman', 89),
#  ('whether', 89),
#  ('water', 88),
#  ('shall', 87),
#  ("won't", 87),
#  ('dark', 87),
#  ('home', 87),
#  ('wish', 86),
#  ('word', 86),
#  ('years', 86),
#  ('book', 86),
#  ('follow', 86),
#  ('value', 86),
#  ('children', 85),
#  ('alive', 85),
#  ('action', 85),
#  ('read', 85),
#  ('given', 85),
#  ('beyond', 85),
#  ('far', 84),
#  ('sense', 84),
#  ('hate', 84),
#  ("didn't", 84),
#  ('moments', 84),
#  ('listen', 84),
#  ('already', 83),
#  ('writing', 83),
#  ('set', 83),
#  ('happens', 83),
#  ('.', 82),
#  ('old', 82),
#  ('art', 81),
#  ('run', 81),
#  ('born', 81),
#  ('sure', 81),
#  ('desire', 81),
#  ('lies', 81),
#  ('’', 81),
#  ('against', 80),
#  ('meet', 80),
#  ('maybe', 80),
#  ('left', 80),
#  ('full', 79),
#  ('hands', 78),
#  ('women', 78),
#  ('sun', 78),
#  ('–', 77),
#  ('behind', 76),
#  ('fact', 76),
#  ('show', 76),
#  ('easy', 76),
#  ('gift', 76),
#  ('order', 76),
#  ('point', 76),
#  ('simply', 76),
#  ('trust', 75),
#  ('hand', 74),
#  ("i'd", 74),
#  ('head', 74),
#  ('broken', 74),
#  ('lot', 74),
#  ('meant', 73),
#  ('next', 73),
#  ('goals', 73),
#  ("they're", 73),
#  ('learned', 72),
#  ('possible', 72),
#  ('nor', 72),
#  ('difference', 72),
#  ('himself', 71),
#  ('spend', 71),
#  ('ideas', 71),
#  ('fight', 71),
#  ('high', 70),
#  ('itself', 70),
#  ('allow', 70),
#  ('hear', 70),
#  ('hearts', 70),
#  ('ways', 70),
#  ("what's", 70),
#  ('shine', 70),
#  ('failure', 70),
#  ('dance', 70),
#  ('ability', 69),
#  ('play', 69),
#  ('greater', 69),
#  ('road', 69),
#  ('call', 68),
#  ('imagination', 68),
#  ('voice', 68),
#  ('realize', 68),
#  ('child', 68),
#  ('break', 68),
#  ('books', 68),
#  ('wisdom', 68),
#  ('seek', 68),
#  ('matters', 68),
#  ('problems', 67),
#  ('loving', 67),
#  ('inner', 67),
#  ('felt', 67),
#  ('negative', 67),
#  ('energy', 67),
#  ('told', 67),
#  ('gives', 66),
#  ('knowledge', 66),
#  ('rise', 65),
#  ('comfort', 65),
#  ('knows', 64),
#  ('build', 64),
#  ('single', 64),
#  ("i'll", 64),
#  ('becomes', 64),
#  ('music', 63),
#  ('above', 63),
#  ('along', 63),
#  ('knowing', 63),
#  ('lead', 63),
#  ('either', 63),
#  ('giving', 62),
#  ('both', 62),
#  ('simple', 62),
#  ('vision', 62),
#  ('share', 61),
#  ('enjoy', 61),
#  ('grace', 61),
#  ('outside', 61),
#  ('answer', 61),
#  ('heaven', 61),
#  ('seen', 61),
#  ('morning', 60),
#  ('s', 60),
#  ('mistakes', 60),
#  ('friend', 60),
#  ('money', 60),
#  ('used', 60),
#  ('silence', 60),
#  ('powerful', 60),
#  ('sit', 60),
#  ('speak', 59),
#  ('chance', 59),
#  ('short', 59),
#  ('difficult', 59),
#  ('appreciate', 58),
#  ('worry', 58),
#  ('needs', 58),
#  ('getting', 58),
#  ('fail', 58),
#  ('talk', 58),
#  ('few', 57),
#  ('learning', 57),
#  ('seems', 57),
#  ("life's", 57),
#  ('touch', 57),
#  ('magic', 57),
#  ('under', 57),
#  ('fire', 56),
#  ('attention', 56),
#  ('ready', 56),
#  ('decide', 56),
#  ('brave', 56),
#  ('grateful', 55),
#  ('amazing', 55),
#  ('respect', 55),
#  ('gets', 55),
#  ('personal', 55),
#  ('wants', 55),
#  ("one's", 55),
#  ('longer', 55),
#  ('travel', 55),
#  ('close', 55),
#  ('wings', 54),
#  ('fears', 54),
#  ('least', 54),
#  ('potential', 54),
#  ('willing', 54),
#  ('goes', 54),
#  ('passion', 54),
#  ('mine', 54),
#  ('destiny', 54),
#  ('existence', 53),
#  ('problem', 53),
#  ('opportunity', 53),
#  ('growth', 53),
#  ('fly', 53),
#  ('came', 52),
#  ('knew', 52),
#  ('young', 52),
#  ('idea', 52),
#  ('meaning', 52),
#  ('kindness', 51),
#  ('souls', 51),
#  ('goal', 51),
#  ('expect', 50),
#  ('wise', 50),
#  ('towards', 50),
#  ('wonderful', 50),
#  ('girl', 50),
#  ('name', 50),
#  ('higher', 50),
#  ('year', 50),
#  ('memories', 50),
#  ('‘', 50),
#  ('moving', 50),
#  ('actually', 50),
#  ('toward', 50),
#  ('wonder', 50),
#  ('treat', 50),
#  ('space', 50),
#  ('language', 49),
#  ('feet', 49),
#  ('thank', 49),
#  ('lived', 49),
#  ('beginning', 49),
#  ('state', 49),
#  ('divine', 49),
#  ('created', 49),
#  ('family', 49),
#  ('..', 49),
#  ('return', 49),
#  ('war', 49),
#  ('choices', 49),
#  ('wanted', 49),
#  ('successful', 48),
#  ('opportunities', 48),
#  ('waste', 48),
#  ('writer', 48),
#  ('feelings', 48),
#  ('stronger', 48),
#  ('doubt', 48),
#  ('actions', 48),
#  ("god's", 48),
#  ('stories', 48),
#  ('begins', 48),
#  ('responsibility', 48),
#  ('taking', 48),
#  ('deserve', 48),
#  ('infinite', 48),
#  ('daily', 48),
#  ('dare', 48),
#  ('forgive', 47),
#  ('hurt', 47),
#  ('everyday', 47),
#  ('question', 47),
#  ('discover', 47),
#  ('exist', 47),
#  ('lord', 47),
#  ('however', 46),
#  ('form', 46),
#  ('teach', 46),
#  ('places', 46),
#  ('secret', 46),
#  ('called', 46),
#  ('direction', 46),
#  ('tears', 46),
#  ('minds', 45),
#  ('air', 45),
#  ('master', 45),
#  ('unless', 45),
#  ("aren't", 45),
#  ('saying', 45),
#  ('embrace', 45),
#  ('t', 45),
#  ('loves', 45),
#  ('gone', 45),
#  ('situation', 45),
#  ('entire', 44),
#  ('win', 44),
#  ('thousand', 44),
#  ('challenge', 44),
#  ("we've", 44),
#  ('watch', 44),
#  ('yes', 44),
#  ('confidence', 44),
#  ('exactly', 44),
#  ('changes', 44),
#  ('promise', 44),
#  ('rain', 44),
#  ('half', 44),
#  ('plan', 44),
#  ('experiences', 44),
#  ('understanding', 44),
#  ('regret', 43),
#  ('feels', 43),
#  ('relationship', 43),
#  ('presence', 43),
#  ('known', 43),
#  ('course', 43),
#  ('met', 43),
#  ('impossible', 43),
#  ('greatness', 43),
#  ('says', 43),
#  ('bit', 43),
#  ('room', 43),
#  ('key', 42),
#  ('keeps', 42),
#  ('laugh', 42),
#  ('trees', 42),
#  ('process', 42),
#  ('unique', 42),
#  ('written', 42),
#  ('tree', 42),
#  ('finding', 42),
#  ('moon', 42),
#  ('black', 42),
#  ('star', 42),
#  ('certain', 42),
#  ('ordinary', 41),
#  ('character', 41),
#  ('looks', 41),
#  ('somewhere', 41),
#  ('since', 41),
#  ('effort', 41),
#  ('save', 41),
#  ('emotions', 41),
#  ('bright', 41),
#  ('friendship', 41),
#  ('lack', 41),
#  ('almost', 40),
#  ('wind', 40),
#  ('remain', 40),
#  ('poor', 40),
#  ('suffering', 40),
#  ('breath', 40),
#  ('yesterday', 40),
#  ('wild', 40),
#  ('patience', 40),
#  ('carry', 40),
#  ('rich', 40),
#  ('three', 39),
#  ('door', 39),
#  ('started', 39),
#  ('spiritual', 39),
#  ('evil', 39),
#  ('seem', 39),
#  ('nobody', 39),
#  ('succeed', 39),
#  ('christ', 38),
#  ('compassion', 38),
#  ('wake', 38),
#  ('ocean', 38),
#  ('finally', 38),
#  ('attitude', 38),
#  ('growing', 37),
#  ('quiet', 37),
#  ('soon', 37),
#  ('possibilities', 37),
#  ('creation', 37),
#  ('coming', 37),
#  ('practice', 37),
#  ('pretty', 37),
#  ('none', 37),
#  ('define', 37),
#  ('reading', 37),
#  ('dead', 37),
#  ('adventure', 37),
#  ('anger', 37),
#  ('limit', 37),
#  ('heal', 37),
#  ('memory', 37),
#  ('telling', 37),
#  ('necessary', 37),
#  ('mother', 36),
#  ('everybody', 36),
#  ('color', 36),
#  ('prayer', 36),
#  ('count', 36),
#  ('inspire', 36),
#  ('whom', 36),
#  ('belief', 36),
#  ('river', 36),
#  ('circumstances', 36),
#  ('highest', 36),
#  ('education', 35),
#  ('okay', 35),
#  ('whose', 35),
#  ('force', 35),
#  ('took', 35),
#  ('perhaps', 35),
#  ('across', 35),
#  ('walking', 35),
#  ('pleasure', 35),
#  ('fill', 35),
#  ('cause', 35),
#  ('happened', 35),
#  ('second', 35),
#  ('receive', 35),
#  ('neither', 35),
#  ('job', 35),
#  ('brain', 35),
#  ('habits', 35),
#  ('ahead', 35),
#  ('sight', 35),
#  ('perfection', 35),
#  ('eat', 35),
#  ('risk', 35),
#  ('sea', 35),
#  ('continue', 35),
#  ('clear', 34),
#  ('skin', 34),
#  ('destination', 34),
#  ('protect', 34),
#  ('throw', 34),
#  ('anymore', 34),
#  ('special', 34),
#  ('eye', 34),
#  ('sad', 34),
#  ("let's", 34),
#  ('arms', 34),
#  ('kill', 34),
#  ('song', 34),
#  ('ends', 34),
#  ('humanity', 34),
#  ('beings', 34),
#  ('side', 34),
#  ('opinions', 34),
#  ('result', 33),
#  ('top', 33),
#  ('habit', 33),
#  ('ground', 33),
#  ('exists', 33),
#  ('zone', 33),
#  ('asked', 33),
#  ('sound', 33),
#  ('blessed', 33),
#  ('serve', 33),
#  ('overcome', 33),
#  ('holding', 33),
#  ('mistake', 33),
#  ("man's", 33),
#  ('standing', 33),
#  ('pray', 33),
#  ('miss', 33),
#  ('age', 33),
#  ('discipline', 33),
#  ('decision', 32),
#  ('hours', 32),
#  ('imagine', 32),
#  ('line', 32),
#  ('common', 32),
#  ('sing', 32),
#  ('crazy', 32),
#  ('essence', 32),
#  ('inspired', 32),
#  ('brings', 32),
#  ('capable', 32),
#  ('struggle', 32),
#  ('humility', 32),
#  ('white', 32),
#  ('kept', 32),
#  ('land', 32),
#  ('lucky', 32),
#  ('leaves', 32),
#  ('breathe', 32),
#  ('pass', 32),
#  ('cut', 31),
#  ('business', 31),
#  ('needed', 31),
#  ('hell', 31),
#  ('happening', 31),
#  ('letting', 31),
#  ('empty', 31),
#  ('offer', 31),
#  ('kids', 31),
#  ('anyway', 31),
#  ('flow', 31),
#  ('unknown', 31),
#  ('eternal', 31),
#  ('calm', 31),
#  ('simplicity', 30),
#  ('looked', 30),
#  ('jesus', 30),
#  ('working', 30),
#  ('number', 30),
#  ('easier', 30),
#  ('silent', 30),
#  ('extraordinary', 30),
#  ('hit', 30),
#  ('worst', 30),
#  ('wherever', 30),
#  ('tried', 30),
#  ('believing', 30),
#  ('lips', 30),
#  ('pride', 30),
#  ('heard', 30),
#  ('sleep', 30),
#  ('pure', 30),
#  ('worthy', 30),
#  ('cry', 30),
#  ('honest', 30),
#  ('filled', 30),
#  ('relationships', 30),
#  ('creativity', 30),
#  ('fun', 30),
#  ('seeing', 30),
#  ('storm', 29),
#  ('accomplish', 29),
#  ('motivation', 29),
#  ('especially', 29),
#  ('natural', 29),
#  ('laughter', 29),
#  ('changed', 29),
#  ('front', 29),
#  ('hidden', 29),
#  ('later', 29),
#  ('gave', 29),
#  ('individual', 29),
#  ('planet', 29),
#  ('fate', 29),
#  ('please', 29),
#  ('apart', 29),
#  ('late', 29),
#  ('kiss', 29),
#  ('percent', 29),
#  ('forgotten', 29),
#  ("couldn't", 29),
#  ('fool', 29),
#  ('worrying', 29),
#  ("she's", 29),
#  ('level', 28),
#  ('deeply', 28),
#  ('except', 28),
#  ('hour', 28),
#  ('animal', 28),
#  ('anybody', 28),
#  ('usually', 28),
#  ('judge', 28),
#  ('burn', 28),
#  ('believed', 28),
#  ('fit', 28),
#  ('country', 28),
#  ("world's", 28),
#  ('despair', 28),
#  ('million', 28),
#  ("people's", 28),
#  ('belong', 28),
#  ('saw', 28),
#  ('strive', 28),
#  ('lie', 28),
#  ('wear', 28),
#  ("wouldn't", 28),
#  ('limits', 28),
#  ('blood', 28),
#  ('results', 28),
#  ('vast', 28),
#  ('hundred', 28),
#  ('hero', 28),
#  ('sorrow', 28),
#  ('celebrate', 28),
#  ('running', 28),
#  ('shape', 28),
#  ('drive', 28),
#  ('false', 28),
#  ('pick', 28),
#  ('till', 27),
#  ('gifts', 27),
#  ('talent', 27),
#  ('gotta', 27),
#  ('blessings', 27),
#  ('oh', 27),
#  ('chase', 27),
#  ('otherwise', 27),
#  ('distance', 27),
#  ('leads', 27),
#  ('house', 27),
#  ('limitations', 27),
#  ('suffer', 27),
#  ('youth', 27),
#  ('condition', 27),
#  ('page', 27),
#  ('safe', 27),
#  ('caring', 27),
#  ('therefore', 27),
#  ('anywhere', 27),
#  ('harder', 26),
#  ('religion', 26),
#  ('shines', 26),
#  ('society', 26),
#  ('merely', 26),
#  ('taken', 26),
#  ("else's", 26),
#  ('hide', 26),
#  ('aim', 26),
#  ('recognize', 26),
#  ('turns', 26),
#  ('thankful', 26),
#  ('cold', 26),
#  ('flower', 26),
#  ('falling', 26),
#  ('parents', 26),
#  ('helps', 26),
#  ('miracles', 26),
#  ('advice', 26),
#  ('pay', 26),
#  ('jump', 26),
#  ('quite', 26),
#  ('treasure', 26),
#  ('creative', 26),
#  ('changing', 26),
#  ('ultimate', 26),
#  ('onto', 25),
#  ('sacrifice', 25),
#  ('speaking', 25),
#  ('mirror', 25),
#  ('sunshine', 25),
#  ('mountains', 25),
#  ('events', 25),
#  ('tranquility', 25),
#  ('honor', 25),
#  ('complete', 25),
#  ('worse', 25),
#  ('push', 25),
#  ('during', 25),
#  ('remind', 25),
#  ('precious', 25),
#  ('ought', 25),
#  ('parts', 25),
#  ('stupid', 25),
#  ('miracle', 25),
#  ('blue', 25),
#  ('father', 25),
#  ('achievement', 25),
#  ('minute', 25),
#  ('school', 25),
#  ('thinks', 25),
#  ('amount', 25),
#  ('weak', 25),
#  ('holy', 25),
#  ('expectations', 25),
#  ('bear', 25),
#  ('dying', 25),
#  ('constantly', 25),
#  ('cross', 24),
#  ('fighting', 24),
#  ...]

# %% [markdown]
# ## Printing the most 2k common words in pseudo-profound (vacuous) inputs

# %%
vacuous  = vacuous_counts.most_common(2000)
vacuous_pos = pos_tag([v[0] for v in vacuous])
g = open('vacuous_wordlist.txt','w')

for i in range (0,2000):
    g.write(vacuous[i][0] + '\t' +  vacuous_pos[i][1] + '\t' + str(vacuous[i][1]) + '\n')
g.close()

# %% [markdown]
# ## Printing the most 2k common words in non-pseudo-profound (mundane) inputs

# %%
mundane  = mundane_counts.most_common(2000)
mundane_pos= pos_tag([m[0] for m in mundane])
f = open('mundane_wordlist.txt','w')

for i in range (0,2000):
    f.write(mundane[i][0] + '\t' +  mundane_pos[i][1] + '\t' + str(mundane[i][1]) + '\n')
f.close()

# %% [markdown]
# ## Inspect the ratios of mundane to vacuous of a certain word
# (Needs to be run for later t-SNE plotting)

# %%
mundane_vacuous_ratios = Counter()
mundane_vacuous_raw_ratios = Counter()
for word, cnt in list(total_counts.most_common()):
    if(cnt > 10):
        mundane_vacuous_ratio = mundane_counts[word] / float(vacuous_counts[word]+1)
        mundane_vacuous_ratios[word] = mundane_vacuous_ratio
        
mundane_vacuous_raw_ratios = mundane_vacuous_ratios #saving the raw ratios before taking logarithms

# %%
print("MUN / QUO raw ratio for 'possible' = {}".format(mundane_vacuous_ratios["possible"]))
print("MUN / QUO raw ratio for 'believe' = {}".format(mundane_vacuous_ratios["believe"]))
# Out:
# MUN / QUO raw ratio for 'possible' = 2.2739726027397262
# MUN / QUO raw ratio for 'believe' = 0.8390804597701149

# %%
for word, ratio in mundane_vacuous_ratios.most_common():
    mundane_vacuous_ratios[word] = np.log(ratio + 0.01)

# %%
print("MUN / QUO log ratio for 'possible' = {}".format(mundane_vacuous_ratios["possible"]))
print("MUN / QUO log ratio for 'believe' = {}".format(mundane_vacuous_ratios["believe"]))
# Out:
# MUN / QUO log ratio for 'possible' = 0.8259162964239763
# MUN / QUO log ratio for 'believe' = -0.16360132711393735

# %%
mundane_vacuous_ratios.most_common()
# Out:
# [('president', 6.385211262261948),
#  ('trump', 5.945446786274408),
#  ('scientific', 5.921605228935918),
#  ('police', 5.488979047616993),
#  ('thursday', 5.39367299986479),
#  ('science', 5.366690045755508),
#  ('donald', 5.164843115148066),
#  ('florida', 5.043489630967203),
#  ('political', 5.004013417787369),
#  ('obama', 4.997279839049098),
#  ('california', 4.962914557884844),
#  ('festival', 4.962914557884844),
#  ('park', 4.87527365616558),
#  ('members', 4.8041030085872425),
#  ('protesters', 4.78757507264335),
#  ('military', 4.770769366637658),
#  ('residents', 4.753676394287315),
#  ('national', 4.72304210658298),
#  ('china', 4.709620287344555),
#  ('politics', 4.654055583717902),
#  ('minister', 4.654055583717902),
#  ('korea', 4.634826070895602),
#  ('ceremony', 4.615219521841093),
#  ('york', 4.610257225036649),
#  ('korean', 4.605270180988425),
#  ('england', 4.574814065973192),
#  ('wednesday', 4.564452352709533),
#  ('british', 4.564452352709533),
#  ('india', 4.553982149218658),
#  ('former', 4.532707014254376),
#  ('officials', 4.532707014254376),
#  ('texas', 4.442768896629268),
#  ('central', 4.442768896629268),
#  ('french', 4.4309358393767555),
#  ("trump's", 4.418961082466944),
#  ('photo', 4.388381400311889),
#  ('january', 4.382151626862033),
#  ('injured', 4.343935283551159),
#  ('11', 4.290596418067994),
#  ('authorities', 4.248638088989106),
#  ('14', 4.248638088989106),
#  ('announced', 4.234251421632511),
#  ('region', 4.219654753187547),
#  ('memorial', 4.219654753187547),
#  ('duchess', 4.20484186198508),
#  ('schools', 4.20484186198508),
#  ('tuesday', 4.2011040987936346),
#  ('hurricane', 4.182202802743785),
#  ('saturday', 4.159039321153912),
#  ('southern', 4.159039321153912),
#  ('democratic', 4.159039321153912),
#  ('anniversary', 4.159039321153912),
#  ('2018', 4.143293443953964),
#  ('flooding', 4.143293443953964),
#  ('2016', 4.127295662361787),
#  ('kim', 4.127295662361787),
#  ('friday', 4.100050474719743),
#  ('temperatures', 4.094511215001422),
#  ('carolina', 4.094511215001422),
#  ('capitol', 4.094511215001422),
#  ('washington', 4.086144365656761),
#  ('republican', 4.077706921069077),
#  ('june', 4.060615409477973),
#  ('protest', 4.025530246221741),
#  ('hong', 4.025530246221741),
#  ('february', 4.007514986887367),
#  ('island', 4.007514986887367),
#  ('rally', 4.007514986887367),
#  ('april', 3.9891692146047997),
#  ('mexico', 3.9891692146047997),
#  ('virginia', 3.9891692146047997),
#  ('hillary', 3.9704805749997147),
#  ('un', 3.9514360077849813),
#  ('flag', 3.9514360077849813),
#  ('biology', 3.9514360077849813),
#  ('fans', 3.932021691934835),
#  ('los', 3.932021691934835),
#  ('earthquake', 3.932021691934835),
#  ('parliament', 3.932021691934835),
#  ('annual', 3.9221713364799613),
#  ('reported', 3.9122229854308124),
#  ('video', 3.898802667257291),
#  ("city's", 3.8920243589214563),
#  ('cambridge', 3.8920243589214563),
#  ('address', 3.8920243589214563),
#  ('iraq', 3.8920243589214563),
#  ('northern', 3.8714093225428488),
#  ('prime', 3.8714093225428488),
#  ('50', 3.8714093225428488),
#  ('lunar', 3.8714093225428488),
#  ('syria', 3.8714093225428488),
#  ('site', 3.8714093225428488),
#  ('officer', 3.8714093225428488),
#  ('genetic', 3.8714093225428488),
#  ('russian', 3.850360345036039),
#  ('pope', 3.850360345036039),
#  ('village', 3.850360345036039),
#  ('refugees', 3.850360345036039),
#  ('historic', 3.850360345036039),
#  ('aerial', 3.850360345036039),
#  ('turkey', 3.850360345036039),
#  ('flooded', 3.8288587641673772),
#  ('wildfires', 3.8288587641673772),
#  ('meghan', 3.806884687304841),
#  ('nasa', 3.806884687304841),
#  ('scientists', 3.788951007838152),
#  ('border', 3.784416880823),
#  ('2017', 3.784416880823),
#  ('angeles', 3.784416880823),
#  ('tourists', 3.784416880823),
#  ('solar', 3.784416880823),
#  ('awards', 3.784416880823),
#  ('province', 3.784416880823),
#  ('13', 3.784416880823),
#  ('congress', 3.784416880823),
#  ('syrian', 3.784416880823),
#  ('south', 3.779862101825807),
#  ('physics', 3.7768140159483843),
#  ('largest', 3.7614326467956447),
#  ('chinese', 3.7614326467956447),
#  ('named', 3.7614326467956447),
#  ('launched', 3.7614326467956447),
#  ('senate', 3.7614326467956447),
#  ('north', 3.7379076851812907),
#  ('michigan', 3.7379076851812907),
#  ('douglas', 3.7379076851812907),
#  ('sunday', 3.713815939403968),
#  ('olympics', 3.713815939403968),
#  ('august', 3.713815939403968),
#  ('migrants', 3.713815939403968),
#  ('kong', 3.713815939403968),
#  ('year-old', 3.6891294228691436),
#  ("britain's", 3.6891294228691436),
#  ('2015', 3.6891294228691436),
#  ('sciences', 3.6765538044232993),
#  ('st', 3.6765538044232993),
#  ('november', 3.663818023518565),
#  ('santa', 3.663818023518565),
#  ('actor', 3.663818023518565),
#  ('investigation', 3.663818023518565),
#  ('zealand', 3.663818023518565),
#  ('capital', 3.6509179478268177),
#  ('presidential', 3.6509179478268177),
#  ('officially', 3.6378492830011573),
#  ('islands', 3.6378492830011573),
#  ('democracy', 3.6378492830011573),
#  ('ii', 3.6378492830011573),
#  ('december', 3.6378492830011573),
#  ('historical', 3.6378492830011573),
#  ('marjory', 3.6378492830011573),
#  ('stoneman', 3.6378492830011573),
#  ('w', 3.6378492830011573),
#  ('international', 3.6111881463980646),
#  ('15', 3.6111881463980646),
#  ('rio', 3.6111881463980646),
#  ('flint', 3.6111881463980646),
#  ('melania', 3.6111881463980646),
#  ('group', 3.6044102974874863),
#  ('government', 3.5975861956675455),
#  ('economics', 3.583796677660784),
#  ('category', 3.583796677660784),
#  ('officers', 3.583796677660784),
#  ('drone', 3.583796677660784),
#  ('isis', 3.583796677660784),
#  ('camp', 3.5698143469549963),
#  ('technology', 3.5651097842695973),
#  ('research', 3.5651097842695973),
#  ('march', 3.555633734966574),
#  ('sydney', 3.555633734966574),
#  ('debate', 3.555633734966574),
#  ('russia', 3.555633734966574),
#  ('demonstrators', 3.555633734966574),
#  ('racial', 3.555633734966574),
#  ('19', 3.555633734966574),
#  ('voters', 3.555633734966574),
#  ('michelle', 3.555633734966574),
#  ('francis', 3.555633734966574),
#  ('dc', 3.555633734966574),
#  ('population', 3.541249137109912),
#  ('monday', 3.526654599019104),
#  ('global', 3.526654599019104),
#  ('17', 3.526654599019104),
#  ('arrested', 3.526654599019104),
#  ('muslims', 3.526654599019104),
#  ('activists', 3.526654599019104),
#  ('german', 3.526654599019104),
#  ('parkland', 3.526654599019104),
#  ('2014', 3.526654599019104),
#  ('london', 3.5207566167197943),
#  ('campaign', 3.4968105458651015),
#  ('recent', 3.4968105458651015),
#  ('12', 3.4968105458651015),
#  ('october', 3.4968105458651015),
#  ('lava', 3.4968105458651015),
#  ('spotted', 3.4968105458651015),
#  ('japan', 3.481547734315814),
#  ('scientist', 3.4738280726970627),
#  ('solidarity', 3.4660483539817717),
#  ('celebrates', 3.4660483539817717),
#  ('27', 3.4660483539817717),
#  ('hawaii', 3.4660483539817717),
#  ('resident', 3.4660483539817717),
#  ('court', 3.4343097331123578),
#  ('climate', 3.4343097331123578),
#  ('france', 3.4343097331123578),
#  ('australia', 3.4343097331123578),
#  ('marking', 3.4343097331123578),
#  ('acres', 3.4343097331123578),
#  ('immigration', 3.4343097331123578),
#  ('politicians', 3.4343097331123578),
#  ('organisms', 3.4343097331123578),
#  ('fleeing', 3.4343097331123578),
#  ('cherry', 3.4343097331123578),
#  ('pyeongchang', 3.4343097331123578),
#  ('bang', 3.4343097331123578),
#  ('brazil', 3.4343097331123578),
#  ('volcano', 3.418054498728578),
#  ('africa', 3.418054498728578),
#  ('photographer', 3.4125768338490876),
#  ('georgia', 3.4015306594522756),
#  ('engineering', 3.4015306594522756),
#  ('evacuated', 3.4015306594522756),
#  ('eastern', 3.4015306594522756),
#  ('mural', 3.4015306594522756),
#  ('mosul', 3.4015306594522756),
#  ('erupted', 3.4015306594522756),
#  ('200', 3.4015306594522756),
#  ('funeral', 3.4015306594522756),
#  ('civil', 3.367640598133313),
#  ('method', 3.367640598133313),
#  ('jong', 3.367640598133313),
#  ('passengers', 3.367640598133313),
#  ('21', 3.367640598133313),
#  ('maduro', 3.367640598133313),
#  ('lawmakers', 3.367640598133313),
#  ('greece', 3.367640598133313),
#  ('nominee', 3.367640598133313),
#  ('canadian', 3.367640598133313),
#  ('philippines', 3.367640598133313),
#  ('secretary', 3.367640598133313),
#  ('massive', 3.356083783965147),
#  ('uk', 3.3502549029245805),
#  ('american', 3.339676525013905),
#  ('coast', 3.332561589272017),
#  ('rescue', 3.332561589272017),
#  ('empirical', 3.332561589272017),
#  ('ideology', 3.332561589272017),
#  ('helicopter', 3.332561589272017),
#  ('sen', 3.332561589272017),
#  ('rep', 3.332561589272017),
#  ('irma', 3.332561589272017),
#  ('manchester', 3.332561589272017),
#  ('venezuela', 3.332561589272017),
#  ('macron', 3.332561589272017),
#  ('tweeted', 3.332561589272017),
#  ('puerto', 3.332561589272017),
#  ('theory', 3.3253956682458736),
#  ('election', 3.308472745346549),
#  ('square', 3.2962071678045244),
#  ("women's", 3.2962071678045244),
#  ('protests', 3.2962071678045244),
#  ('jr', 3.2962071678045244),
#  ('maria', 3.2962071678045244),
#  ('tokyo', 3.2962071678045244),
#  ('selection', 3.2962071678045244),
#  ('las', 3.2962071678045244),
#  ('miami', 3.2962071678045244),
#  ('physicist', 3.2962071678045244),
#  ('staff', 3.2962071678045244),
#  ('tens', 3.2962071678045244),
#  ('iconic', 3.2962071678045244),
#  ('actress', 3.2962071678045244),
#  ('east', 3.277522020300934),
#  ('germany', 3.277522020300934),
#  ('vote', 3.2712152385487743),
#  ('general', 3.26804686887465),
#  ('workers', 3.25848107946056),
#  ('statue', 3.25848107946056),
#  ('gunman', 3.25848107946056),
#  ('kavanaugh', 3.25848107946056),
#  ('berlin', 3.25848107946056),
#  ('league', 3.25848107946056),
#  ('technical', 3.25848107946056),
#  ('myanmar', 3.25848107946056),
#  ('houston', 3.25848107946056),
#  ('academy', 3.25848107946056),
#  ('immigrants', 3.25848107946056),
#  ('1,000', 3.25848107946056),
#  ('navy', 3.25848107946056),
#  ('vietnam', 3.25848107946056),
#  ('28', 3.25848107946056),
#  ('mayor', 3.25848107946056),
#  ('darwin', 3.25848107946056),
#  ('scott', 3.25848107946056),
#  ('fundamental', 3.23907053215372),
#  ('history', 3.2315034520359727),
#  ('party', 3.219275744889528),
#  ('americans', 3.219275744889528),
#  ('australian', 3.219275744889528),
#  ('elected', 3.219275744889528),
#  ('observed', 3.219275744889528),
#  ('administration', 3.219275744889528),
#  ('estimated', 3.219275744889528),
#  ('increasingly', 3.219275744889528),
#  ('bangladesh', 3.219275744889528),
#  ('variety', 3.219275744889528),
#  ('inauguration', 3.219275744889528),
#  ('22', 3.219275744889528),
#  ('ministry', 3.219275744889528),
#  ('tower', 3.2058581277868976),
#  ('william', 3.1990811975400213),
#  ('biological', 3.1990811975400213),
#  ('policy', 3.1990811975400213),
#  ('hundreds', 3.1888289035159043),
#  ('shooting', 3.1867657709499673),
#  ('local', 3.178470410233162),
#  ('buildings', 3.178470410233162),
#  ('parade', 3.178470410233162),
#  ('hospital', 3.178470410233162),
#  ('instagram', 3.178470410233162),
#  ('airport', 3.178470410233162),
#  ('hypothesis', 3.178470410233162),
#  ('afghanistan', 3.178470410233162),
#  ('district', 3.178470410233162),
#  ('drove', 3.178470410233162),
#  ('concert', 3.178470410233162),
#  ('northeast', 3.178470410233162),
#  ('killed', 3.1738319678521223),
#  ('sexual', 3.164490034341609),
#  ('united', 3.157425862551978),
#  ('photos', 3.1503114329993167),
#  ('facebook', 3.1359289040472746),
#  ('dozens', 3.1359289040472746),
#  ('sussex', 3.1359289040472746),
#  ('swipe', 3.1359289040472746),
#  ('legal', 3.1359289040472746),
#  ('environmental', 3.1359289040472746),
#  ('louis', 3.1359289040472746),
#  ('equations', 3.1359289040472746),
#  ('technologies', 3.1359289040472746),
#  ('britain', 3.1359289040472746),
#  ('factory', 3.1359289040472746),
#  ('committee', 3.1359289040472746),
#  ('joint', 3.1359289040472746),
#  ('iraqi', 3.1359289040472746),
#  ('landfall', 3.1359289040472746),
#  ('atheist', 3.1359289040472746),
#  ('spanish', 3.1359289040472746),
#  ('demonstration', 3.1359289040472746),
#  ('candidate', 3.1359289040472746),
#  ('eclipse', 3.1359289040472746),
#  ('coastal', 3.1359289040472746),
#  ('stadium', 3.1359289040472746),
#  ('astronaut', 3.1359289040472746),
#  ('crew', 3.1359289040472746),
#  ('official', 3.113959654918641),
#  ('tour', 3.113959654918641),
#  ('genes', 3.113959654918641),
#  ('groups', 3.113959654918641),
#  ('released', 3.1065279917017565),
#  ('died', 3.0914968955383704),
#  ('systems', 3.0914968955383704),
#  ('firefighters', 3.0914968955383704),
#  ('phenomenon', 3.0914968955383704),
#  ('chicago', 3.0914968955383704),
#  ('tourist', 3.0914968955383704),
#  ('hollywood', 3.0914968955383704),
#  ('criminal', 3.0914968955383704),
#  ("china's", 3.0914968955383704),
#  ('putin', 3.0914968955383704),
#  ('posted', 3.0914968955383704),
#  ("korea's", 3.0914968955383704),
#  ('minnesota', 3.0914968955383704),
#  ('marine', 3.0914968955383704),
#  ('damaged', 3.0914968955383704),
#  ('dakota', 3.0914968955383704),
#  ('pakistan', 3.0914968955383704),
#  ('operations', 3.0914968955383704),
#  ('timelapse', 3.0914968955383704),
#  ('charges', 3.0914968955383704),
#  ('contemporary', 3.0914968955383704),
#  ('physicists', 3.0914968955383704),
#  ('widespread', 3.0914968955383704),
#  ('indonesia', 3.0914968955383704),
#  ('attorney', 3.0914968955383704),
#  ('flights', 3.0914968955383704),
#  ('van', 3.0914968955383704),
#  ("america's", 3.0914968955383704),
#  ('displaced', 3.0914968955383704),
#  ('18', 3.068517943279639),
#  ('royal', 3.0607394348626014),
#  ('john', 3.0607394348626014),
#  ('duke', 3.044998514856909),
#  ('evolutionary', 3.044998514856909),
#  ('visitors', 3.044998514856909),
#  ('nomination', 3.044998514856909),
#  ('havana', 3.044998514856909),
#  ('vatican', 3.044998514856909),
#  ('laboratory', 3.044998514856909),
#  ('polls', 3.044998514856909),
#  ('relative', 3.044998514856909),
#  ('mph', 3.044998514856909),
#  ('justin', 3.044998514856909),
#  ('falcon', 3.044998514856909),
#  ('democrats', 3.044998514856909),
#  ('beijing', 3.044998514856909),
#  ('proposed', 3.044998514856909),
#  ('markle', 3.044998514856909),
#  ('journalism', 3.044998514856909),
#  ('barcelona', 3.044998514856909),
#  ('terrorist', 3.044998514856909),
#  ('johnson', 3.044998514856909),
#  ('controversial', 3.044998514856909),
#  ('downtown', 3.044998514856909),
#  ('jersey', 3.044998514856909),
#  ('sandy', 3.044998514856909),
#  ('discussion', 3.044998514856909),
#  ('indonesian', 3.044998514856909),
#  ('week', 3.031932695951877),
#  ('town', 3.0160249768217535),
#  ('traditional', 3.012753257888294),
#  ('clinton', 3.012753257888294),
#  ('weekend', 3.012753257888294),
#  ('city', 3.0079223772939847),
#  ('george', 2.996232148595642),
#  ("country's", 2.996232148595642),
#  ('voting', 2.996232148595642),
#  ('medieval', 2.996232148595642),
#  ('brett', 2.996232148595642),
#  ('christianity', 2.996232148595642),
#  ('governor', 2.996232148595642),
#  ('conference', 2.996232148595642),
#  ('alaska', 2.996232148595642),
#  ('vegas', 2.996232148595642),
#  ("london's", 2.996232148595642),
#  ('deadliest', 2.996232148595642),
#  ('rohingya', 2.996232148595642),
#  ('network', 2.996232148595642),
#  ('ryan', 2.996232148595642),
#  ('saudi', 2.996232148595642),
#  ('locals', 2.996232148595642),
#  ('thai', 2.996232148595642),
#  ('missouri', 2.996232148595642),
#  ('spacecraft', 2.996232148595642),
#  ('orlando', 2.996232148595642),
#  ('rico', 2.996232148595642),
#  ('rubble', 2.996232148595642),
#  ('troops', 2.996232148595642),
#  ('scotland', 2.996232148595642),
#  ('aleppo', 2.996232148595642),
#  ('massachusetts', 2.996232148595642),
#  ('consensus', 2.996232148595642),
#  ('system', 2.9906638954424287),
#  ('earlier', 2.983659692319722),
#  ('supporters', 2.97092715463502),
#  ('gun', 2.97092715463502),
#  ('cell', 2.97092715463502),
#  ('japanese', 2.97092715463502),
#  ('six', 2.9580304063699794),
#  ('including', 2.9524519025581566),
#  ('beach', 2.944965156500338),
#  ('sites', 2.944965156500338),
#  ('oscar', 2.944965156500338),
#  ('darwinian', 2.944965156500338),
#  ('republic', 2.944965156500338),
#  ('darwinism', 2.944965156500338),
#  ('ford', 2.944965156500338),
#  ('alongside', 2.944965156500338),
#  ('psychology', 2.944965156500338),
#  ('grounds', 2.944965156500338),
#  ('snowfall', 2.944965156500338),
#  ('istanbul', 2.944965156500338),
#  ('vehicles', 2.944965156500338),
#  ('heritage', 2.944965156500338),
#  ('westminster', 2.944965156500338),
#  ('29', 2.944965156500338),
#  ('shortly', 2.944965156500338),
#  ('civilians', 2.944965156500338),
#  ('mccain', 2.944965156500338),
#  ('dancers', 2.944965156500338),
#  ('sports', 2.944965156500338),
#  ('migrant', 2.944965156500338),
#  ('aircraft', 2.944965156500338),
#  ('icon', 2.944965156500338),
#  ('mike', 2.944965156500338),
#  ('software', 2.944965156500338),
#  ('shutdown', 2.944965156500338),
#  ("york's", 2.944965156500338),
#  ('illegal', 2.944965156500338),
#  ('veterans', 2.944965156500338),
#  ('sparked', 2.944965156500338),
#  ('kenya', 2.944965156500338),
#  ('century', 2.9272749729090837),
#  ('mathematics', 2.9272749729090837),
#  ('bush', 2.9272749729090837),
#  ('de', 2.9183111265854063),
#  ('magnitude', 2.9183111265854063),
#  ('degrees', 2.9183111265854063),
#  ('launch', 2.9183111265854063),
#  ('explosion', 2.9183111265854063),
#  ('organized', 2.9183111265854063),
#  ('organization', 2.9183111265854063),
#  ('during', 2.916231085898686),
#  ('according', 2.907867385574315),
#  ('area', 2.9001387202698607),
#  ('community', 2.9001387202698607),
#  ('numbers', 2.8909271591878647),
#  ('celebrations', 2.8909271591878647),
#  ('afternoon', 2.8909271591878647),
#  ('molecules', 2.8909271591878647),
#  ('activist', 2.8909271591878647),
#  ('colorado', 2.8909271591878647),
#  ('balloons', 2.8909271591878647),
#  ('data', 2.7938200669950324),
#  ('gathered', 2.7887081041196646),
#  ('mass', 2.785628335747585),
#  ('thousands', 2.7835698747490154),
#  ('barack', 2.7732135270086236),
#  ('ban', 2.7732135270086236),
#  ('african', 2.7732135270086236),
#  ('european', 2.7732135270086236),
#  ('computers', 2.7732135270086236),
#  ('era', 2.7732135270086236),
#  ('award', 2.7732135270086236),
#  ('zoo', 2.7732135270086236),
#  ('elections', 2.7732135270086236),
#  ('stock', 2.7732135270086236),
#  ('arizona', 2.7732135270086236),
#  ('customers', 2.7732135270086236),
#  ('projects', 2.7732135270086236),
#  ('protesting', 2.7732135270086236),
#  ('feminist', 2.7732135270086236),
#  ('resort', 2.7732135270086236),
#  ('minority', 2.7732135270086236),
#  ('unveiled', 2.7732135270086236),
#  ('feature', 2.7732135270086236),
#  ('kilauea', 2.7732135270086236),
#  ('metal', 2.7732135270086236),
#  ('males', 2.7732135270086236),
#  ('findings', 2.7732135270086236),
#  ('2007', 2.7732135270086236),
#  ('nicolas', 2.7732135270086236),
#  ('gulf', 2.7732135270086236),
#  ('bicycle', 2.7732135270086236),
#  ('eiffel', 2.7732135270086236),
#  ("japan's", 2.7732135270086236),
#  ('particle', 2.7732135270086236),
#  ('jet', 2.7732135270086236),
#  ('scientifically', 2.7732135270086236),
#  ('pipeline', 2.7732135270086236),
#  ('typhoon', 2.7732135270086236),
#  ('liberal', 2.7732135270086236),
#  ('worker', 2.7732135270086236),
#  ('baseball', 2.7732135270086236),
#  ('volcanic', 2.7732135270086236),
#  ('rescuers', 2.7732135270086236),
#  ('towers', 2.7732135270086236),
#  ('conservative', 2.7732135270086236),
#  ('photographed', 2.7732135270086236),
#  ('guests', 2.7732135270086236),
#  ('louisiana', 2.7732135270086236),
#  ('150', 2.7732135270086236),
#  ('tennis', 2.7732135270086236),
#  ('lee', 2.7732135270086236),
#  ('kensington', 2.7732135270086236),
#  ('measuring', 2.7732135270086236),
#  ('president-elect', 2.7732135270086236),
#  ('richard', 2.7732135270086236),
#  ('ai', 2.7732135270086236),
#  ('rescued', 2.7732135270086236),
#  ('31', 2.7732135270086236),
#  ('manhattan', 2.7732135270086236),
#  ('museum', 2.757475084429733),
#  ('month', 2.755206377979987),
#  ('nearly', 2.7495119909098045),
#  ('west', 2.7479117345273405),
#  ('modern', 2.7450604958718032),
#  ('europe', 2.7414849771884473),
#  ('atlanta', 2.7414849771884473),
#  ('objective', 2.7414849771884473),
#  ('studies', 2.7414849771884473),
#  ('range', 2.7414849771884473),
#  ('joined', 2.7414849771884473),
#  ('weeks', 2.7350166493320245),
#  ('violence', 2.7350166493320245),
#  ('theories', 2.7306810691610406),
#  ('economy', 2.7306810691610406),
#  ('developed', 2.7306810691610406),
#  ('department', 2.7306810691610406),
#  ('species', 2.7275726771148654),
#  ('25', 2.7087166456453704),
#  ("men's", 2.7087166456453704),
#  ('pictured', 2.7087166456453704),
#  ('mount', 2.7087166456453704),
#  ('report', 2.7087166456453704),
#  ('2019', 2.7087166456453704),
#  ('dr', 2.7087166456453704),
#  ('bill', 2.506341930508065),
#  ('machines', 2.506341930508065),
#  ('giant', 2.506341930508065),
#  ('muslim', 2.485739636091892),
#  ('7', 2.485739636091892),
#  ('visited', 2.485739636091892),
#  ('fireworks', 2.485739636091892),
#  ('charles', 2.485739636091892),
#  ('catholic', 2.485739636091892),
#  ('services', 2.485739636091892),
#  ('removed', 2.485739636091892),
#  ('founded', 2.485739636091892),
#  ('classes', 2.485739636091892),
#  ('empire', 2.485739636091892),
#  ('decade', 2.485739636091892),
#  ('canada', 2.485739636091892),
#  ('operation', 2.485739636091892),
#  ('asia', 2.485739636091892),
#  ('supplies', 2.485739636091892),
#  ('flat', 2.485739636091892),
#  ('galaxy', 2.485739636091892),
#  ('performed', 2.485739636091892),
#  ('barackobama', 2.485739636091892),
#  ('lab', 2.485739636091892),
#  ('genome', 2.485739636091892),
#  ('emerged', 2.485739636091892),
#  ('economists', 2.485739636091892),
#  ('upper', 2.485739636091892),
#  ('72', 2.485739636091892),
#  ('detained', 2.485739636091892),
#  ('chile', 2.485739636091892),
#  ('sexually', 2.485739636091892),
#  ('publicly', 2.485739636091892),
#  ('materialism', 2.485739636091892),
#  ('executive', 2.485739636091892),
#  ('spacex', 2.485739636091892),
#  ('agreed', 2.485739636091892),
#  ('neural', 2.485739636091892),
#  ('hurricaneirma', 2.485739636091892),
#  ('89th', 2.485739636091892),
#  ('pairs', 2.485739636091892),
#  ('origins', 2.485739636091892),
#  ('accessible', 2.485739636091892),
#  ('gop', 2.485739636091892),
#  ('turkish', 2.485739636091892),
#  ('sport', 2.485739636091892),
#  ('angela', 2.485739636091892),
#  ('assumed', 2.485739636091892),
#  ('cyclone', 2.485739636091892),
#  ('secular', 2.485739636091892),
#  ('gravitational', 2.485739636091892),
#  ("bush's", 2.485739636091892),
#  ('responded', 2.485739636091892),
#  ('molecular', 2.485739636091892),
#  ('humanitarian', 2.485739636091892),
#  ('tournament', 2.485739636091892),
#  ('harrison', 2.485739636091892),
#  ('maine', 2.485739636091892),
#  ('skyline', 2.485739636091892),
#  ('protein', 2.485739636091892),
#  ('pedestrians', 2.485739636091892),
#  ('unified', 2.485739636091892),
#  ('costume', 2.485739636091892),
#  ('1960s', 2.485739636091892),
#  ('asian', 2.485739636091892),
#  ('council', 2.485739636091892),
#  ('galileo', 2.485739636091892),
#  ('ginsburg', 2.485739636091892),
#  ('beyonce', 2.485739636091892),
#  ...]

# %%
list(reversed(mundane_vacuous_ratios.most_common()))
# Out:
# [('stumble', -4.605170185988091),
#  ('wishing', -4.605170185988091),
#  ('darkest', -4.605170185988091),
#  ('adversity', -2.962942450731),
#  ('wanna', -2.962942450731),
#  ('muse', -2.7704856720430024),
#  ('flaws', -2.7704856720430024),
#  ('blank', -2.724857319418591),
#  ('rainbows', -2.676209595246551),
#  ('yours', -2.676209595246551),
#  ('regrets', -2.624168717121508),
#  ('dont', -2.624168717121508),
#  ('sorrow', -2.538744012420326),
#  ('shine', -2.5204608533733968),
#  ('mindful', -2.5080290672088545),
#  ('authentic', -2.5080290672088545),
#  ('dig', -2.4427317247372877),
#  ('adventures', -2.4427317247372877),
#  ('tranquility', -2.4427317247372877),
#  ('empower', -2.371577964480997),
#  ('roar', -2.371577964480997),
#  ('crawl', -2.371577964480997),
#  ('unconditional', -2.371577964480997),
#  ('hurts', -2.371577964480997),
#  ('forgive', -2.371577964480997),
#  ("life's", -2.3412542341531997),
#  ('yourself', -2.321942223683654),
#  ('brilliance', -2.2935352574741277),
#  ('aspire', -2.2935352574741277),
#  ('worthwhile', -2.2935352574741277),
#  ('fulfilling', -2.2935352574741277),
#  ('achieving', -2.2935352574741277),
#  ('greatness', -2.2935352574741277),
#  ('forgiveness', -2.2515299221937615),
#  ('loneliness', -2.160537435338031),
#  ('blessings', -2.1443610877791515),
#  ('gotta', -2.1443610877791515),
#  ('dwell', -2.111046881095167),
#  ('dreams', -2.0891436274862865),
#  ('grab', -2.058486176503848),
#  ('ruin', -2.058486176503848),
#  ('seeds', -2.0024805005437076),
#  ('christ', -1.9790162612087407),
#  ('nurture', -1.9425823589626385),
#  ("everyone's", -1.9425823589626385),
#  ('whisper', -1.9425823589626385),
#  ('worrying', -1.9425823589626385),
#  ('angel', -1.8782515005814986),
#  ('mindset', -1.8782515005814986),
#  ('longing', -1.8782515005814986),
#  ('roots', -1.8782515005814986),
#  ('fullest', -1.8088273777402029),
#  ('negativity', -1.8088273777402029),
#  ('soar', -1.8088273777402029),
#  ('your', -1.8005339949370422),
#  ('solitude', -1.7844180623696873),
#  ('quiet', -1.7844180623696873),
#  ('heal', -1.7844180623696873),
#  ('inspiration', -1.7719568419318752),
#  ('grace', -1.7643953692312988),
#  ('impress', -1.7334905611040792),
#  ('builds', -1.7334905611040792),
#  ('serenity', -1.7334905611040792),
#  ('shallow', -1.7334905611040792),
#  ('encouragement', -1.7334905611040792),
#  ("someone's", -1.7334905611040792),
#  ('settle', -1.7334905611040792),
#  ('inspires', -1.6794817561670268),
#  ('riches', -1.6794817561670268),
#  ('warmth', -1.6794817561670268),
#  ('scars', -1.6794817561670268),
#  ('smile', -1.6794817561670268),
#  ('talent', -1.6682784124570338),
#  ("you've", -1.6578114967183162),
#  ('love', -1.6528629137120319),
#  ('masterpiece', -1.6512073253103954),
#  ('wont', -1.6512073253103954),
#  ('anguish', -1.6512073253103954),
#  ('seize', -1.6512073253103954),
#  ('hardship', -1.6512073253103954),
#  ('scare', -1.6512073253103954),
#  ('weary', -1.6512073253103954),
#  ('healing', -1.6512073253103954),
#  ('destiny', -1.6512073253103954),
#  ('passion', -1.6512073253103954),
#  ('positive', -1.63185219455646),
#  ('worry', -1.627394786554059),
#  ('glad', -1.607059790029133),
#  ('soul', -1.607059790029133),
#  ('loving', -1.6035727929817023),
#  ('self', -1.5931841684895933),
#  ('okay', -1.587459005715325),
#  ('breath', -1.584150592719451),
#  ('grateful', -1.5778008274909179),
#  ('grey', -1.5606477482646683),
#  ("it'll", -1.5606477482646683),
#  ('assurance', -1.5606477482646683),
#  ('obstacle', -1.5606477482646683),
#  ('throat', -1.5606477482646683),
#  ('tender', -1.2632725466072279),
#  ('karma', -1.2632725466072279),
#  ('cultivate', -1.2632725466072279),
#  ('drops', -1.2632725466072279),
#  ('wings', -1.2632725466072279),
#  ('gift', -1.2632725466072279),
#  ('loved', -1.2632725466072279),
#  ('focus', -1.2562305119428314),
#  ('succeed', -1.2552660987134865),
#  ('calm', -1.2335732741022267),
#  ("i've", -1.2279419944389323),
#  ('meditation', -1.2183615417780356),
#  ('jealous', -1.2183615417780356),
#  ('manifest', -1.2183615417780356),
#  ('chooses', -1.2183615417780356),
#  ('sadness', -1.2183615417780356),
#  ('comfort', -1.211068627307405),
#  ('souls', -1.2091142038263547),
#  ('trust', -1.2057287310282008),
#  ('forever', -1.2039728043259361),
#  ('paths', -1.1984326239503205),
#  ('hurt', -1.1984326239503205),
#  ('freely', -1.1903406555358782),
#  ('cherish', -1.1903406555358782),
#  ('inspire', -1.1799396048817796),
#  ('mindfulness', -1.171182981502945),
#  ('planted', -1.171182981502945),
#  ('glow', -1.171182981502945),
#  ('ease', -1.171182981502945),
#  ('pointing', -1.171182981502945),
#  ('laughing', -1.171182981502945),
#  ('seasons', -1.171182981502945),
#  ('motivation', -1.171182981502945),
#  ('wait', -1.1677203741652122),
#  ('endure', -1.1572551797584762),
#  ('roses', -1.1466719504885952),
#  ('faithful', -1.1466719504885952),
#  ('remind', -1.1466719504885952),
#  ('expectations', -1.1466719504885952),
#  ('courage', -1.1427425951509562),
#  ('thoughts', -1.1402642735527917),
#  ('afraid', -1.1373127488269374),
#  ('goals', -1.1369037040226477),
#  ('stay', -1.1359680752118786),
#  ('conquer', -1.1316521427463098),
#  ('wonderful', -1.1278593747922891),
#  ('lovely', -1.1215038924699356),
#  ('focused', -1.114187500453581),
#  ('candle', -1.114187500453581),
#  ('deepest', -1.1086626245216111),
#  ('till', -1.1043429633770947),
#  ('gifts', -1.1043429633770947),
#  ('discipline', -1.0980242263165554),
#  ('loves', -1.0903853533298191),
#  ('forget', -1.089704710776997),
#  ('write', -1.0760626971511948),
#  ('sights', -1.0690534864265653),
#  ('passions', -1.0690534864265653),
#  ('virtues', -1.0690534864265653),
#  ('priority', -1.0690534864265653),
#  ('innocence', -1.0690534864265653),
#  ('awaken', -1.0690534864265653),
#  ('bless', -1.0690534864265653),
#  ('grains', -1.0690534864265653),
#  ('possessions', -1.0690534864265653),
#  ('treasures', -1.0690534864265653),
#  ('limitless', -1.0690534864265653),
#  ('cared', -1.0690534864265653),
#  ('flesh', -1.0690534864265653),
#  ('bury', -1.0690534864265653),
#  ('sings', -1.0690534864265653),
#  ('lover', -1.0690534864265653),
#  ('ear', -1.0690534864265653),
#  ('criticize', -1.0690534864265653),
#  ('shoulder', -1.0690534864265653),
#  ('figured', -1.0690534864265653),
#  ('troubles', -1.0690534864265653),
#  ('fortune', -1.0690534864265653),
#  ('brand', -1.0690534864265653),
#  ('cool', -1.0690534864265653),
#  ('strengths', -1.0690534864265653),
#  ('fearless', -1.0690534864265653),
#  ('stops', -1.0690534864265653),
#  ('unto', -1.0690534864265653),
#  ('grief', -1.0690534864265653),
#  ('thankful', -1.0690534864265653),
#  ('friendship', -1.0690534864265653),
#  ('decide', -1.0690534864265653),
#  ('lose', -1.061127002313082),
#  ("don't", -1.0610781675114391),
#  ('beautiful', -1.0565235643214226),
#  ('..', -1.0498221244986776),
#  ('limit', -1.0438251050263034),
#  ('journey', -1.040898473536461),
#  ('anyway', -1.0391648300246896),
#  ('willing', -1.0343578988010962),
#  ('choice', -1.032392489363394),
#  ('broken', -1.030953640194295),
#  ("you'd", -1.0277082012401713),
#  ('door', -1.0216512475319814),
#  ('failure', -1.0157998557635173),
#  ('lovers', -1.0135145061389195),
#  ('thy', -1.0135145061389195),
#  ('blessed', -1.0135145061389195),
#  ('wise', -1.0135145061389195),
#  ('someone', -1.0135145061389195),
#  ("i'll", -1.011024154957695),
#  ('worthy', -1.0082999143571172),
#  ('life', -1.0069245307521821),
#  ('butterfly', -1.0020042501481847),
#  ('ok', -1.0020042501481847),
#  ('hated', -1.0020042501481847),
#  ('amazing', -1.0020042501481847),
#  ('compassion', -0.99702812523037),
#  ('mistakes', -0.9924815778834327),
#  ('pain', -0.9912537703476103),
#  ('bloody', -0.9844722442902273),
#  ('sing', -0.9844722442902273),
#  ('worth', -0.9790398102437415),
#  ('laughter', -0.9763946559438605),
#  ('stronger', -0.974590252711593),
#  ('scared', -0.9717478074334852),
#  ('mess', -0.9717478074334852),
#  ('miserable', -0.9717478074334852),
#  ('writing', -0.9700934378671313),
#  ('myself', -0.9683817925585033),
#  ('waiting', -0.9675840262617056),
#  ('hide', -0.9666098420638622),
#  ('appreciate', -0.9600301134258075),
#  ('sleeping', -0.9545119446943529),
#  ('attract', -0.9545119446943529),
#  ('sword', -0.9545119446943529),
#  ('flame', -0.9545119446943529),
#  ('awake', -0.9545119446943529),
#  ('lord', -0.9545119446943529),
#  ('everyday', -0.9545119446943529),
#  ('spend', -0.9545119446943529),
#  ('beauty', -0.9527197652835158),
#  ('never', -0.9452148103940456),
#  ('despair', -0.9433784518249034),
#  ('nights', -0.9391695142590861),
#  ('situations', -0.9391695142590861),
#  ('bliss', -0.9391695142590861),
#  ('fix', -0.9391695142590861),
#  ('fears', -0.9369573686827141),
#  ('fulfillment', -0.9298436982788585),
#  ('steal', -0.9298436982788585),
#  ('damn', -0.9298436982788585),
#  ('innocent', -0.9298436982788585),
#  ('ears', -0.9298436982788585),
#  ('brilliant', -0.9298436982788585),
#  ('enjoy', -0.9235752642887841),
#  ('sometimes', -0.9229332983101916),
#  ('dawn', -0.9190723748360319),
#  ('weakness', -0.9190723748360319),
#  ('ending', -0.9190723748360319),
#  ('fail', -0.9167145504861357),
#  ('keep', -0.9147294513072025),
#  ('limitations', -0.9091732641052911),
#  ('feel', -0.9080927202705517),
#  ('crazy', -0.9064904272758629),
#  ('hearts', -0.9054343829083429),
#  ('fear', -0.8983028041383848),
#  ('backwards', -0.8915981192837835),
#  ('elevate', -0.8915981192837835),
#  ('wash', -0.8915981192837835),
#  ('dreamer', -0.8915981192837835),
#  ('saving', -0.8915981192837835),
#  ('cracks', -0.8915981192837835),
#  ('convince', -0.8915981192837835),
#  ('awful', -0.8915981192837835),
#  ('favourite', -0.8915981192837835),
#  ('trials', -0.8915981192837835),
#  ('pages', -0.8915981192837835),
#  ('enthusiasm', -0.8915981192837835),
#  ('deeds', -0.8915981192837835),
#  ('accomplish', -0.8915981192837835),
#  ('anymore', -0.8915981192837835),
#  ('thank', -0.8915981192837835),
#  ('mine', -0.8915981192837835),
#  ('perfect', -0.8865818057801506),
#  ('advice', -0.8736925379526441),
#  ('happy', -0.8732104197086298),
#  ('shadows', -0.8696674157898133),
#  ('dies', -0.8633076894446872),
#  ('spark', -0.8633076894446872),
#  ('treat', -0.8633076894446872),
#  ('moments', -0.8633076894446872),
#  ('hate', -0.8633076894446872),
#  ('master', -0.860280319731236),
#  ('touch', -0.8585099064085305),
#  ('live', -0.8574890849670221),
#  ('imperfections', -0.8517522107365838),
#  ('arrogance', -0.8517522107365838),
#  ('lasts', -0.8517522107365838),
#  ('goddess', -0.8517522107365838),
#  ('habits', -0.8517522107365838),
#  ('laugh', -0.8472203440118304),
#  ('want', -0.8445924930952972),
#  ('misery', -0.8415250813014624),
#  ('adventure', -0.8415250813014624),
#  ('promise', -0.8388154197058645),
#  ('mirror', -0.8368399153099377),
#  ('sacrifice', -0.8368399153099377),
#  ('always', -0.8263778665215494),
#  ('liked', -0.8242325874562075),
#  ('chest', -0.8242325874562075),
#  ('strengthen', -0.8242325874562075),
#  ('helpless', -0.8242325874562075),
#  ('fingers', -0.8242325874562075),
#  ('secrets', -0.8242325874562075),
#  ('anywhere', -0.8242325874562075),
#  ('feelings', -0.8242325874562075),
#  ('path', -0.8211929790488552),
#  ("they'll", -0.8101696359656145),
#  ('dreamed', -0.8101696359656145),
#  ('voice', -0.8101696359656145),
#  ('give', -0.8063963110204695),
#  ('step', -0.8052530843573031),
#  ('option', -0.804078741267227),
#  ('noise', -0.804078741267227),
#  ('hardest', -0.804078741267227),
#  ('go', -0.7986887490404271),
#  ('feed', -0.7985076962177716),
#  ('greatest', -0.7985076962177716),
#  ('habit', -0.7958967286770513),
#  ('keeps', -0.7943818523042137),
#  ('stop', -0.789927828728245),
#  ('autumn', -0.788679607281509),
#  ('haunted', -0.788679607281509),
#  ('conversations', -0.788679607281509),
#  ('99', -0.788679607281509),
#  ('spaces', -0.788679607281509),
#  ('pour', -0.788679607281509),
#  ('maturity', -0.788679607281509),
#  ('compromise', -0.788679607281509),
#  ('frustration', -0.788679607281509),
#  ('decides', -0.788679607281509),
#  ('greed', -0.788679607281509),
#  ('stays', -0.788679607281509),
#  ('spiritually', -0.788679607281509),
#  ('bridges', -0.788679607281509),
#  ('tired', -0.788679607281509),
#  ('confidence', -0.788679607281509),
#  ('me', -0.7837392968632284),
#  ('pick', -0.78028395726132),
#  ('thou', -0.7765287894989963),
#  ('refuse', -0.7765287894989963),
#  ('excellence', -0.7765287894989963),
#  ('creativity', -0.7730286109167868),
#  ('jesus', -0.7730286109167868),
#  ('simplicity', -0.7730286109167868),
#  ('heaven', -0.7730286109167868),
#  ('doubts', -0.7666958685827575),
#  ('anxiety', -0.7666958685827575),
#  ('realised', -0.7666958685827575),
#  ('canvas', -0.7666958685827575),
#  ('lust', -0.7666958685827575),
#  ('outward', -0.7666958685827575),
#  ('sail', -0.7666958685827575),
#  ('diamonds', -0.7666958685827575),
#  ('anew', -0.7666958685827575),
#  ('generous', -0.7666958685827575),
#  ('boring', -0.7666958685827575),
#  ('potential', -0.7666958685827575),
#  ('sad', -0.7611201641461512),
#  ('destination', -0.7611201641461512),
#  ('listening', -0.7585749858824006),
#  ('truly', -0.7567609593355364),
#  ('prayer', -0.7561733323912108),
#  ('remember', -0.7539033899810177),
#  ('optimism', -0.7517546075134166),
#  ('sincere', -0.7517546075134166),
#  ('affection', -0.7517546075134166),
#  ('wake', -0.7517546075134166),
#  ('doing', -0.7509268682702219),
#  ('die', -0.7502168081084389),
#  ('matters', -0.7470372838611401),
#  ('realize', -0.7470372838611401),
#  ('learn', -0.7428555743924086),
#  ('ambition', -0.7409378443962937),
#  ('wounds', -0.7409378443962937),
#  ('dull', -0.7409378443962937),
#  ('hell', -0.7365767384872813),
#  ('waste', -0.7352454994398051),
#  ('difficulties', -0.7327444351843045),
#  ('meaningful', -0.7327444351843045),
#  ('mistake', -0.7327444351843045),
#  ("can't", -0.7281753342418447),
#  ('acceptance', -0.7263230427988449),
#  ('staying', -0.7263230427988449),
#  ('dreaming', -0.7263230427988449),
#  ('anger', -0.7263230427988449),
#  ('telling', -0.7263230427988449),
#  ('define', -0.7263230427988449),
#  ('sit', -0.7227617220598114),
#  ('soft', -0.7211548055468489),
#  ("i'm", -0.719942621740472),
#  ('eternity', -0.7169054471787978),
#  ('embrace', -0.7169054471787978),
#  ('tough', -0.7133498878774648),
#  ('ignore', -0.7133498878774648),
#  ('divine', -0.7133498878774648),
#  ('anyone', -0.7127073175742307),
#  ('silent', -0.7054809948155538),
#  ('bad', -0.7044609404602187),
#  ("let's", -0.7017555550965455),
#  ('throw', -0.7017555550965455),
#  ('desire', -0.6975470898825544),
#  ('happen', -0.6810941270753964),
#  ('person', -0.6764420653426538),
#  ('wasting', -0.6733445532637656),
#  ('edges', -0.6733445532637656),
#  ('wandering', -0.6733445532637656),
#  ('loose', -0.6733445532637656),
#  ('wakes', -0.6733445532637656),
#  ('owe', -0.6733445532637656),
#  ('contemplate', -0.6733445532637656),
#  ('weird', -0.6733445532637656),
#  ('bother', -0.6733445532637656),
#  ('priceless', -0.6733445532637656),
#  ('self-confidence', -0.6733445532637656),
#  ('expand', -0.6733445532637656),
#  ('pause', -0.6733445532637656),
#  ('ladder', -0.6733445532637656),
#  ('brick', -0.6733445532637656),
#  ('tune', -0.6733445532637656),
#  ('haters', -0.6733445532637656),
#  ('sink', -0.6733445532637656),
#  ('dirt', -0.6733445532637656),
#  ('imperfection', -0.6733445532637656),
#  ('generosity', -0.6733445532637656),
#  ('sustain', -0.6733445532637656),
#  ('cake', -0.6733445532637656),
#  ('improvement', -0.6733445532637656),
#  ('rejection', -0.6733445532637656),
#  ('unseen', -0.6733445532637656),
#  ('farther', -0.6733445532637656),
#  ('wisely', -0.6733445532637656),
#  ('unhappy', -0.6733445532637656),
#  ('integrity', -0.6733445532637656),
#  ('uncomfortable', -0.6733445532637656),
#  ('poet', -0.6733445532637656),
#  ('funny', -0.6733445532637656),
#  ('oneself', -0.6733445532637656),
#  ('peaceful', -0.6733445532637656),
#  ('smiling', -0.6733445532637656),
#  ('choosing', -0.6733445532637656),
#  ('precious', -0.6733445532637656),
#  ('accept', -0.6733445532637656),
#  ('begin', -0.6535340797226025),
#  ('eyes', -0.6488275125690227),
#  ('am', -0.6476901612498674),
#  ('circumstances', -0.64719243522532),
#  ('humility', -0.6440684577389655),
#  ('honest', -0.6422087878522238),
#  ('others', -0.6395680908905573),
#  ('jump', -0.637677434515584),
#  ('things', -0.6352902082827875),
#  ('comfortable', -0.6316022662300688),
#  ('creates', -0.6277162006393544),
#  ('absence', -0.6230321319318071),
#  ('ready', -0.6230321319318071),
#  ('fill', -0.620309856607679),
#  ('ones', -0.6193357483267132),
#  ('noble', -0.6172760577878426),
#  ("person's", -0.6172760577878426),
#  ('eternal', -0.6138739996654374),
#  ('fulfill', -0.6100322738494387),
#  ('struggles', -0.6100322738494387),
#  ('excitement', -0.6100322738494387),
#  ("won't", -0.6086389337884341),
#  ('change', -0.6083528713218835),
#  ('else', -0.6073684470211727),
#  ('better', -0.6065819124517587),
#  ('suffer', -0.6056597264368295),
#  ('find', -0.6037367228828088),
#  ('fly', -0.6032387694610405),
#  ('walk', -0.6029590366599864),
#  ('tranquillity', -0.6006381230353321),
#  ('peace', -0.598060115437492),
#  ('count', -0.5968546824055099),
#  ('silence', -0.5960502224362969),
#  ('my', -0.589755043842505),
#  ('self-love', -0.5879684996148666),
#  ("ain't", -0.5879684996148666),
#  ('focusing', -0.5879684996148666),
#  ('extraordinary', -0.5827028352970284),
#  ('definitely', -0.579818495252942),
#  ('humble', -0.579818495252942),
#  ('writer', -0.5779979959334723),
#  ('everyone', -0.5775317345948747),
#  ('knock', -0.569946746773788),
#  ('dedication', -0.569946746773788),
#  ('striving', -0.569946746773788),
#  ('wondering', -0.569946746773788),
#  ('consume', -0.569946746773788),
#  ('wrapped', -0.569946746773788),
#  ('sunsets', -0.569946746773788),
#  ('ass', -0.569946746773788),
#  ('selves', -0.569946746773788),
#  ('maybe', -0.569946746773788),
#  ('unique', -0.5653882304239133),
#  ('alive', -0.5653882304239133),
#  ('need', -0.5640288343795128),
#  ('hatred', -0.5577425435537423),
#  ('shore', -0.5577425435537423),
#  ('forgotten', -0.5504908801584221),
#  ('kiss', -0.5504908801584221),
#  ('presence', -0.5478668954463397),
#  ('try', -0.5451282181580959),
#  ('passes', -0.5422671496008097),
#  ("we'd", -0.5422671496008097),
#  ('stick', -0.5422671496008097),
#  ('fake', -0.5422671496008097),
#  ('approval', -0.5422671496008097),
#  ('chosen', -0.5422671496008097),
#  ("god's", -0.5422671496008097),
#  ('direction', -0.537053101602876),
#  ('tears', -0.537053101602876),
#  ("what's", -0.5319389688324615),
#  ('sin', -0.5294184568426066),
#  ('failures', -0.5294184568426066),
#  ('relationships', -0.5265398457987268),
#  ('fun', -0.5265398457987268),
#  ('wherever', -0.5265398457987268),
#  ('wasted', -0.5219989243641159),
#  ('poison', -0.5219989243641159),
#  ('drama', -0.5219989243641159),
#  ('selfish', -0.5219989243641159),
#  ('cling', -0.5219989243641159),
#  ('lesson', -0.5219989243641159),
#  ('perfection', -0.5219989243641159),
#  ('own', -0.5209273655723127),
#  ('anybody', -0.5171675302912749),
#  ("doesn't", -0.5171675302912749),
#  ('something', -0.5151710950254925),
#  ('careful', -0.5137711339957475),
#  ('spirits', -0.5137711339957475),
#  ('zone', -0.5137711339957475),
#  ('overcome', -0.5137711339957475),
#  ('move', -0.5120168091361438),
#  ('attitude', -0.5112530655335588),
#  ('pursue', -0.5093116189347756),
#  ("shouldn't", -0.5093116189347756),
#  ('helps', -0.5065139447733826),
#  ('growth', -0.5065139447733826),
#  ('make', -0.5061734885246796),
#  ('everything', -0.49920189947183297),
#  ('do', -0.4968610834156183),
#  ("there's", -0.49626153812968554),
#  ('happiest', -0.4942963218147801),
#  ('warrior', -0.4942963218147801),
#  ('yearn', -0.4942963218147801),
#  ('fools', -0.4942963218147801),
#  ('utter', -0.4942963218147801),
#  ('challenging', -0.4942963218147801),
#  ('tie', -0.4942963218147801),
#  ('price', -0.4942963218147801),
#  ('fade', -0.4942963218147801),
#  ('painful', -0.4942963218147801),
#  ('fuel', -0.4942963218147801),
#  ('guy', -0.4942963218147801),
#  ('heights', -0.4942963218147801),
#  ('fault', -0.4942963218147801),
#  ('cares', -0.4942963218147801),
#  ('taste', -0.4942963218147801),
#  ('writers', -0.4942963218147801),
#  ('whatever', -0.4942963218147801),
#  ('makes', -0.4897105601863781),
#  ("one's", -0.48265474679929443),
#  ('happens', -0.48265474679929443),
#  ('smart', -0.48014180382738864),
#  ('create', -0.47961356691141904),
#  ('good', -0.47485796455150986),
#  ('fall', -0.4738307632090312),
#  ('pride', -0.4733641080447231),
#  ('feels', -0.47218783106057666),
#  ('trying', -0.47029996944645214),
#  ('seed', -0.46938843390181745),
#  ('voices', -0.46938843390181745),
#  ('diamond', -0.46938843390181745),
#  ('appreciation', -0.46938843390181745),
#  ('feeling', -0.4667748049604552),
#  ('gonna', -0.463548319189189),
#  ('hero', -0.46094136758369963),
#  ('burn', -0.46094136758369963),
#  ('wish', -0.46094136758369963),
#  ('experiences', -0.4585143291979798),
#  ("we've", -0.4585143291979798),
#  ('break', -0.45698726163391484),
#  ('formula', -0.4541302800894454),
#  ('restless', -0.4541302800894454),
#  ('bold', -0.4541302800894454),
#  ('dictate', -0.4541302800894454),
#  ('improving', -0.4541302800894454),
#  ('laughed', -0.4541302800894454),
#  ('ghosts', -0.4541302800894454),
#  ('drain', -0.4541302800894454),
#  ('purity', -0.4541302800894454),
#  ('novelty', -0.4541302800894454),
#  ('associate', -0.4541302800894454),
#  ('blown', -0.4541302800894454),
#  ('woods', -0.4541302800894454),
#  ('allowing', -0.4541302800894454),
#  ('hug', -0.4541302800894454),
#  ('flow', -0.4541302800894454),
#  ('stand', -0.4541302800894454),
#  ('going', -0.45136157573480157),
#  ('ourselves', -0.4504689711103453),
#  ('take', -0.44821035460471625),
#  ('harder', -0.4468659738457418),
#  ("aren't", -0.4456079854546107),
#  ('unless', -0.4456079854546107),
#  ('swim', -0.44382303567326037),
#  ('possibilities', -0.44382303567326037),
#  ('thing', -0.44313197292951273),
#  ('dance', -0.4403627846976623),
#  ('vision', -0.43862801639189736),
#  ('willingness', -0.436393028983221),
#  ('tales', -0.436393028983221),
#  ('clarity', -0.436393028983221),
#  ('glimpse', -0.436393028983221),
#  ('ashamed', -0.436393028983221),
#  ('devotion', -0.436393028983221),
#  ('losing', -0.436393028983221),
#  ('reflection', -0.436393028983221),
#  ('kept', -0.436393028983221),
#  ('friend', -0.4317922525394859),
#  ('lessons', -0.4307829160924542),
#  ('blame', -0.4307829160924542),
#  ('i', -0.4286450398357183),
#  ('get', -0.4278312804887408),
#  ('concentration', -0.4263969441491999),
#  ('gets', -0.4263969441491999),
#  ('play', -0.4263969441491999),
#  ('best', -0.4240717942921344),
#  ('comes', -0.4237640472331662),
#  ('easier', -0.42287382889285297),
#  ('encounter', -0.41998173097510666),
#  ('mouth', -0.41998173097510666),
#  ('praise', -0.41998173097510666),
#  ('pretend', -0.41998173097510666),
#  ('enemies', -0.41998173097510666),
#  ('herself', -0.41222704902207924),
#  ('victim', -0.41222704902207924),
#  ('what', -0.4113155217863399),
#  ('achievement', -0.40970485236620013),
#  ('belong', -0.40770900306883634),
#  ('song', -0.40475107737450733),
#  ('come', -0.40351049786484244),
#  ('wild', -0.40266415638961334),
#  ('hear', -0.39753885751329976),
#  ('meant', -0.3972556548289111),
#  ('start', -0.39402727373761415),
#  ('absorbed', -0.39057649561441377),
#  ('solitary', -0.39057649561441377),
#  ('enjoyment', -0.39057649561441377),
#  ('honestly', -0.39057649561441377),
#  ('shoot', -0.39057649561441377),
#  ('honesty', -0.39057649561441377),
#  ('yeah', -0.39057649561441377),
#  ('ugly', -0.39057649561441377),
#  ('adult', -0.39057649561441377),
#  ('vain', -0.39057649561441377),
#  ('confident', -0.39057649561441377),
#  ('angry', -0.39057649561441377),
#  ('regardless', -0.39057649561441377),
#  ('shit', -0.39057649561441377),
#  ('granted', -0.39057649561441377),
#  ('mad', -0.39057649561441377),
#  ('luck', -0.39057649561441377),
#  ('catch', -0.39057649561441377),
#  ('miracles', -0.39057649561441377),
#  ('changing', -0.39057649561441377),
#  ('attention', -0.39057649561441377),
#  ('friends', -0.39057649561441377),
#  ('road', -0.3835638441550635),
#  ('light', -0.37863320304514514),
#  ('mind', -0.37428949063971456),
#  ('right', -0.3737325737173231),
#  ('page', -0.3731362209928043),
#  ('oh', -0.3731362209928043),
#  ('glory', -0.3710636813908319),
#  ('secret', -0.369831015595304),
#  ('seek', -0.36938477228712635),
#  ('purpose', -0.3671693788336173),
#  ('sunset', -0.36498001243721717),
#  ('alone', -0.36281621196081487),
#  ('extra', -0.36025276528661637),
#  ('drive', -0.35716767614875056),
#  ('follow', -0.35716767614875056),
#  ('bright', -0.35599490311007687),
#  ('words', -0.3539758869695673),
#  ('revelation', -0.35338366285465966),
#  ('abundance', -0.35338366285465966),
#  ('privilege', -0.35338366285465966),
#  ('hope', -0.3501097159409175),
#  ('lucky', -0.34676747543314157),
#  ('essence', -0.34676747543314157),
#  ('brings', -0.34676747543314157),
#  ('hold', -0.3449216254860618),
#  ('sell', -0.342490308946776),
#  ('loses', -0.342490308946776),
#  ('positively', -0.342490308946776),
#  ('unnecessary', -0.342490308946776),
#  ('writes', -0.342490308946776),
#  ('fancy', -0.342490308946776),
#  ('fantasies', -0.342490308946776),
#  ('sweat', -0.342490308946776),
#  ('bare', -0.342490308946776),
#  ('attained', -0.342490308946776),
#  ('promises', -0.342490308946776),
#  ('realise', -0.342490308946776),
#  ('admire', -0.342490308946776),
#  ('sharing', -0.342490308946776),
#  ('return', -0.342490308946776),
#  ('strong', -0.342490308946776),
#  ('passionate', -0.3342394370567802),
#  ('pen', -0.3342394370567802),
#  ('busy', -0.3342394370567802),
#  ('inspiring', -0.3342394370567802),
#  ('memories', -0.3342394370567802),
#  ('magic', -0.3328237281165525),
#  ('yesterday', -0.3322373141384042),
#  ('sweet', -0.3308215651123985),
#  ('hard', -0.3308215651123985),
#  ('away', -0.3308215651123985),
#  ('cry', -0.328952196040705),
#  ('look', -0.32727655159199165),
#  ('flawed', -0.3225693314522215),
#  ('spell', -0.3225693314522215),
#  ('indifferent', -0.3225693314522215),
#  ('curse', -0.3225693314522215),
#  ('lifestyle', -0.3225693314522215),
#  ('stomach', -0.3225693314522215),
#  ('joys', -0.3225693314522215),
#  ('tightly', -0.3225693314522215),
#  ('pursuing', -0.3225693314522215),
#  ('hello', -0.3225693314522215),
#  ('saints', -0.3225693314522215),
#  ('renewed', -0.3225693314522215),
#  ('concentrate', -0.3225693314522215),
#  ('decent', -0.3225693314522215),
#  ('disappointment', -0.3225693314522215),
#  ('utmost', -0.3225693314522215),
#  ('sunny', -0.3225693314522215),
#  ('accomplishment', -0.3225693314522215),
#  ('rid', -0.3225693314522215),
#  ('smiles', -0.3225693314522215),
#  ('surrender', -0.3225693314522215),
#  ('reach', -0.32049528736123),
#  ('situation', -0.3182907009304171),
#  ('can', -0.31586194833410797),
#  ('climb', -0.31471074483970024),
#  ('accepting', -0.31167122882180354),
#  ('encourage', -0.31167122882180354),
#  ('risk', -0.31167122882180354),
#  ('sight', -0.31167122882180354),
#  ('pleasure', -0.31167122882180354),
#  ('ask', -0.31167122882180354),
#  ("people's", -0.3090583510810859),
#  ('moving', -0.3072180686305298),
#  ('rough', -0.30479740467104893),
#  ('naked', -0.30479740467104893),
#  ('failing', -0.30479740467104893),
#  ('travels', -0.30479740467104893),
#  ('measured', -0.30479740467104893),
#  ('challenges', -0.30479740467104893),
#  ('if', -0.30117736017329355),
#  ('smell', -0.29661070319608235),
#  ('lots', -0.29661070319608235),
#  ('quietly', -0.29661070319608235),
#  ('hang', -0.29661070319608235),
#  ('leave', -0.29661070319608235),
#  ('successful', -0.2947820476622703),
#  ('putting', -0.29190148799448923),
#  ('pretty', -0.29190148799448923),
#  ('somewhere', -0.29022498545589315),
#  ('easy', -0.2873358120605096),
#  ('arms', -0.2838797865020423),
#  ('moment', -0.281228320014289),
#  ('giving', -0.27967191157876364),
#  ('value', -0.2782250160019822),
#  ('enough', -0.2775745953737275),
#  ('anything', -0.2759680050883332),
#  ('silly', -0.2744368457017603),
#  ('uncertainty', -0.2744368457017603),
#  ('judgement', -0.2744368457017603),
#  ('learnt', -0.2744368457017603),
#  ('anxious', -0.2744368457017603),
#  ('fleeting', -0.2744368457017603),
#  ('morally', -0.2744368457017603),
#  ('n', -0.2744368457017603),
#  ('dim', -0.2744368457017603),
#  ('partners', -0.2744368457017603),
#  ('deserves', -0.2744368457017603),
#  ('sorry', -0.2744368457017603),
#  ('badly', -0.2744368457017603),
#  ('stayed', -0.2744368457017603),
#  ('destined', -0.2744368457017603),
#  ('pace', -0.2744368457017603),
#  ('tongue', -0.2744368457017603),
#  ('madness', -0.2744368457017603),
#  ('drink', -0.2744368457017603),
#  ("they've", -0.2744368457017603),
#  ('reflect', -0.2744368457017603),
#  ('distance', -0.2744368457017603),
#  ('knowing', -0.2744368457017603),
#  ('done', -0.26905875378866173),
#  ('way', -0.26905875378866173),
#  ('inside', -0.26644575315375263),
#  ('share', -0.2638815439863748),
#  ("it's", -0.2615628068132519),
#  ('clouds', -0.2613647641344075),
#  ('tell', -0.2607428252198563),
#  ('bigger', -0.2588941019758383),
#  ('lack', -0.2588941019758383),
#  ("that's", -0.2588941019758383),
#  ('lonely', -0.25527182830102646),
#  ('satisfied', -0.25527182830102646),
#  ('determination', -0.25527182830102646),
#  ('abilities', -0.25527182830102646),
#  ('know', -0.25300105085596214),
#  ('reminder', -0.24944803920094466),
#  ('muscles', -0.24944803920094466),
#  ('dying', -0.24944803920094466),
#  ('push', -0.24944803920094466),
#  ('worse', -0.24944803920094466),
#  ('goal', -0.24944803920094466),
#  ('within', -0.24944803920094466),
#  ('deep', -0.2484613592984996),
#  ('responsibility', -0.24142183081497187),
#  ('wet', -0.23853923679218322),
#  ('ll', -0.23853923679218322),
#  ('realizing', -0.23853923679218322),
#  ('frightened', -0.23853923679218322),
#  ('leap', -0.23853923679218322),
#  ('demons', -0.23853923679218322),
#  ('teeth', -0.23853923679218322),
#  ('indifference', -0.23853923679218322),
#  ('productive', -0.23853923679218322),
#  ('expressing', -0.23853923679218322),
#  ('loud', -0.23853923679218322),
#  ('boundaries', -0.23853923679218322),
#  ('falling', -0.23853923679218322),
#  ('walking', -0.23853923679218322),
#  ('again', -0.23853923679218322),
#  ('rich', -0.23510504955085174),
#  ('carry', -0.23510504955085174),
#  ('lies', -0.23510504955085174),
#  ('happening', -0.2341413055237511),
#  ('poets', -0.22851509511612067),
#  ('ability', -0.22851509511612067),
#  ('when', -0.22830619543177436),
#  ('struggle', -0.22579858795826224),
#  ('action', -0.22227183834313008),
#  ('somebody', -0.22106238511038523),
#  ('rest', -0.22106238511038523),
#  ('matter', -0.21986551979676594),
#  ("wouldn't", -0.21927174609022435),
#  ('limits', -0.21927174609022435),
#  ('god', -0.2187737624157893),
#  ('pray', -0.21800969332035794),
#  ('faith', -0.21430590699568214),
#  ('breaks', -0.21072103131565253),
#  ('throws', -0.21072103131565253),
#  ('finish', -0.21072103131565253),
#  ('status', -0.21072103131565253),
#  ('having', -0.2080113697200546),
#  ('allow', -0.2072494083184403),
#  ('true', -0.2069149465078508),
#  ('suffering', -0.20471681033564257),
#  ('believing', -0.2027876299281136),
#  ('enter', -0.19903182749997492),
#  ('patient', -0.19903182749997492),
#  ('character', -0.19903182749997492),
#  ('everybody', -0.197462633586567),
#  ('sick', -0.19540679634261007),
#  ('intuition', -0.19540679634261007),
#  ('see', -0.19442889041745412),
#  ('opportunity', -0.19259638473505286),
#  ("isn't", -0.19172485283193466),
#  ('stories', -0.19076526806655683),
#  ('actions', -0.19076526806655683),
#  ('infinite', -0.19076526806655683),
#  ('run', -0.1898621105667606),
#  ('exploitation', -0.1885225615265035),
#  ('wine', -0.1885225615265035),
#  ('raw', -0.1885225615265035),
#  ('gives', -0.1852512171955496),
#  ('because', -0.18295658118358382),
#  ('will', -0.18217723731160493),
#  ('lift', -0.17902265632846132),
#  ('helping', -0.17902265632846132),
#  ('garden', -0.17902265632846132),
#  ('spirit', -0.17902265632846132),
#  ('head', -0.17832953552441716),
#  ('meet', -0.177739477976688),
#  ('fit', -0.1772310869723929),
#  ('wear', -0.1772310869723929),
#  ('kill', -0.17605551521530816),
#  ('teach', -0.17460671203530287),
#  ('seas', -0.17039298592868077),
#  ('stones', -0.17039298592868077),
#  ('illness', -0.17039298592868077),
#  ('reward', -0.17039298592868077),
#  ('follows', -0.17039298592868077),
#  ('blessing', -0.17039298592868077),
#  ('rise', -0.17039298592868077),
#  ('kind', -0.16680618150939489),
#  ('believe', -0.16360132711393735),
#  ('respect', -0.16335961891256812),
#  ('keeping', -0.16251892949777494),
#  ('gain', -0.16251892949777494),
#  ('imagination', -0.1618371500270163),
#  ('personality', -0.16004521147689674),
#  ...]

# %% [markdown]
# ## Printing the most 2000 polarized mundane and vacuous words

# %%
m_v_ratio  = mundane_vacuous_ratios.most_common(2000)
r_m_v_ratio = list(reversed(mundane_vacuous_ratios.most_common()))
m_v_ratio_pos= pos_tag([m[0] for m in m_v_ratio])
r_m_v_ratio_pos= pos_tag([m[0] for m in r_m_v_ratio])
f = open('mundane_vacuous_ratios.txt','w')
for i in range (0,2000):
    f.write(m_v_ratio[i][0] + '\t' +  m_v_ratio_pos[i][1] + '\t' + str(m_v_ratio[i][1]) + '\n')
f.close()
g = open('revserse_mundane_vacuous_ratios.txt','w')
for i in range (0,2000):
    g.write(r_m_v_ratio[i][0] + '\t' +  r_m_v_ratio_pos[i][1] + '\t' + str(r_m_v_ratio[i][1]) + '\n')
g.close()

# %% [markdown]
# ## The MLP Initialization
# The eval method returns chance of being pseudo-profound according to the trained model with the dataset loaded earlier on

# %%
import time
import sys
import numpy as np
from collections import Counter

class TextClassificationNetwork:
    
    def __init__(self, texts,types,min_count = 10, polarity_cutoff = 0.1, hidden_nodes = 10, learning_rate = 0.1):

        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the texts and their associated types 
        self.pre_process_data(texts, types, polarity_cutoff, min_count)
        
        # Build the network with the number of hidden nodes and the learning rate
        # Make the same number of input nodes as the size of vocabulary
        self.init_network(len(self.text_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, texts, types, polarity_cutoff, min_count):
        
        mundane_counts = Counter()
        vacuous_counts = Counter()
        total_counts = Counter()

        for i in range(len(texts)):
            if(types[i] == 'MUNDANE'):
                for word in texts[i].split(" "):
                    mundane_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in texts[i].split(" "):
                    vacuous_counts[word] += 1
                    total_counts[word] += 1

        mundane_vacuous_ratios = Counter()

        for word, cnt in list(total_counts.most_common()):
            if(cnt >= 5): #threshold of frequency in the data
                mundane_vacuous_ratio = mundane_counts[word] / float(vacuous_counts[word] + 1)
                mundane_vacuous_ratios[word] = mundane_vacuous_ratio

        for word, ratio in mundane_vacuous_ratios.most_common():
            if(ratio > 1):
                mundane_vacuous_ratios[word] = np.log(ratio)
            else:
                mundane_vacuous_ratios[word] = -np.log((1 / (ratio + 0.01)))
                
        # populate text_vocab
        text_vocab = set()
        for text in texts:
            for word in text.split(" "):
                if(total_counts[word] > min_count):
                    if(word in mundane_vacuous_ratios.keys()):
                        if((mundane_vacuous_ratios[word] >= polarity_cutoff) or (mundane_vacuous_ratios[word] <= -polarity_cutoff)):
                            text_vocab.add(word)
                    else:
                        text_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.text_vocab = list(text_vocab)
        
        # populate type_vocab
        type_vocab = set()
        for type in types:
            type_vocab.add(type)
        
        # Convert the type vocabulary set to a list so we can access types via indices
        self.type_vocab = list(type_vocab)
        
        # Store the sizes of the texts and types vocabularies
        self.text_vocab_size = len(self.text_vocab)
        self.type_vocab_size = len(self.type_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.text_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of types mapped to index positions
        self.type2index = {}
        for i, type in enumerate(self.type_vocab):
            self.type2index[type] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights between the input layer and the hidden layer.

        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    def get_target_for_type(self,type):
        if(type == 'MUNDANE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_texts_raw, training_types):

        training_texts = list()
        for text in training_texts_raw:
            indices = set()
            for word in text.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_texts.append(list(indices))

        assert(len(training_texts) == len(training_types))
        
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given texts and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_texts)):
            
            # Get the next text and its correct type
            text = training_texts[i]
            type = training_types[i]
            
            self.layer_1 *= 0
            for index in text:
                self.layer_1 += self.weights_0_1[index]

            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_type(type) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            # Only update the weights that were used in the forward pass
            for index in text:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and type == 'MUNDANE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and type == 'VACUOUS'):
                correct_so_far += 1
            
            # Print out our prediction accuracy and speed throughout the training process. 
            elapsed_time = float(time.time() - start)
            texts_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_texts)))[:4] \
                             + "% Speed(texts/sec):" + str(texts_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_texts, testing_types):

        correct = 0
        true_m = 0
        false_m = 0
        true_v = 0
        false_v = 0
        # Time how many predictions per second we make
        start = time.time()

        for i in range(len(testing_texts)):
            pred = self.run(testing_texts[i])
            if(pred == testing_types[i]):
                correct += 1
                if pred == 'MUNDANE':
                    true_m += 1
                else:
                    true_v += 1
            else:
                if pred == 'MUNDANE':
                    false_m += 1
                else:
                    false_v += 1
                
            # Print out our prediction accuracy and speed throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            texts_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_texts)))[:4] \
                             + "% Speed(texts/sec):" + str(texts_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%" \
                             + "\tTM:" + str(true_m) + "\tPM:" + str(false_m) + "\tTV:" + str(true_v) + "\tPV:" + str(false_v))     
            
    def run(self, text):

        self.layer_1 *= 0
        unique_indices = set()
        for word in text.split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
 
        if(layer_2[0] >= 0.5):
            return "MUNDANE"
        else:
            return "VACUOUS"
        
                
    def eval(self, eval_texts):
        pseudo_profundity = 0
        # Time how many predictions per second we make
        start = time.time()

        for i in range(len(eval_texts)):
            pred = self.run(eval_texts[i])
            if(pred != 'MUNDANE'):
                pseudo_profundity += 1
                
            # Print out our prediction accuracy and speeed throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            texts_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(eval_texts)))[:4] \
                             + "% Speed(texts/sec):" + str(texts_per_second)[0:5] \
                             + " Pseudo-profundity:" + str(pseudo_profundity * 100 / float(i+1))[:4] + "%")

# %% [markdown]
# ## To-do: cross-validate each fold.

# %%
mlp = TextClassificationNetwork(texts[1850:], types[1850:], min_count=5, polarity_cutoff=0.1, learning_rate=0.01)
mlp.train(texts[1850:],types[1850:])
# Out:
# Progress:0.0% Speed(texts/sec):0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:15.0% Speed(texts/sec):2909. #Correct:2009 #Trained:2501 Training Accuracy:80.3%
# Progress:30.0% Speed(texts/sec):2807. #Correct:4107 #Trained:5001 Training Accuracy:82.1%
# Progress:45.0% Speed(texts/sec):2857. #Correct:6252 #Trained:7501 Training Accuracy:83.3%
# Progress:60.0% Speed(texts/sec):2807. #Correct:8436 #Trained:10001 Training Accuracy:84.3%
# Progress:75.0% Speed(texts/sec):2484. #Correct:10603 #Trained:12501 Training Accuracy:84.8%
# Progress:90.0% Speed(texts/sec):2608. #Correct:12780 #Trained:15001 Training Accuracy:85.1%
# Progress:99.9% Speed(texts/sec):2501. #Correct:14214 #Trained:16650 Training Accuracy:85.3%

# %%
mlp.test(texts[:1850],types[:1850])
# Out:
# Progress:67.4% Speed(texts/sec):6139. #Correct:1114 #Tested:1248 Testing Accuracy:89.2%	TM:596	PM:82	TV:518	PV:52
# Progress:99.9% Speed(texts/sec):4930. #Correct:1639 #Tested:1850 Testing Accuracy:88.5%	TM:873	PM:126	TV:766	PV:85

# %% [markdown]
# ## mlpfull trains the complete dataset for eval method and word similarity plotting.

# %%
mlpfull = TextClassificationNetwork(texts, types, min_count=5, polarity_cutoff=0.1, learning_rate=0.01)
mlpfull.train(texts,types)
# Out:
# Progress:0.0% Speed(texts/sec):0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:13.5% Speed(texts/sec):3265. #Correct:2017 #Trained:2501 Training Accuracy:80.6%
# Progress:27.0% Speed(texts/sec):3047. #Correct:4125 #Trained:5001 Training Accuracy:82.4%
# Progress:40.5% Speed(texts/sec):3137. #Correct:6260 #Trained:7501 Training Accuracy:83.4%
# Progress:54.0% Speed(texts/sec):3062. #Correct:8411 #Trained:10001 Training Accuracy:84.1%
# Progress:67.5% Speed(texts/sec):2847. #Correct:10601 #Trained:12501 Training Accuracy:84.8%
# Progress:81.0% Speed(texts/sec):2630. #Correct:12792 #Trained:15001 Training Accuracy:85.2%
# Progress:94.5% Speed(texts/sec):2641. #Correct:14969 #Trained:17501 Training Accuracy:85.5%
# Progress:99.9% Speed(texts/sec):2672. #Correct:15843 #Trained:18500 Training Accuracy:85.6%

# %%
g = open('to_eval.txt','r')
detects = list(map(lambda x:x[:-1].lower(),g.readlines()))
g.close()
#Stemming (optional)
'''
quotes = []
for detect in detects:
    tokens = tknzr.tokenize(detect)
    stems = []
    for token in tokens:
        stems.append(snowball.stem(token))
    tokens = stems
    quotes.append(' '.join([token for token in tokens if token not in punctuation]))
detects = quotes
'''

# %% [markdown]
# ## Dectect chance of being pseudo-profound from to_eval.txt

# %%
mlpfull.eval(detects)
# Out:
# Progress:85.7% Speed(texts/sec):0 Pseudo-profundity:71.4%

# %% [markdown]
# ## Get the most similar words to a given word

# %%
def get_most_similar_words(focus):
    most_similar = Counter()

    for word in mlpfull.word2index.keys():
        most_similar[word] = np.dot(mlpfull.weights_0_1[mlpfull.word2index[word]],mlpfull.weights_0_1[mlpfull.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("society")
# Out:
# [('science', 0.08063560221902141),
#  ('scientific', 0.033385064638252145),
#  ('technology', 0.024457570442375925),
#  ('history', 0.023313607601492946),
#  ('president', 0.023032889531040553),
#  ('”', 0.02277717053487963),
#  ('scientists', 0.022227519466824875),
#  ('universe', 0.021947247292855066),
#  ('scientist', 0.021028346073836888),
#  ('during', 0.01908708106180083),
#  ('said', 0.018647157425357413),
#  ('years', 0.018064521224059438),
#  ('was', 0.01746151015318839),
#  ('human', 0.016801524322413816),
#  ('says', 0.016787687481069114),
#  ('very', 0.01610091066971842),
#  ('—', 0.015866576291924527),
#  ('over', 0.015696268152969237),
#  ('its', 0.015401185570799164),
#  ('politics', 0.015314018384244017),
#  ('which', 0.015133755195603739),
#  ('knowledge', 0.015115885935917998),
#  ('system', 0.014969168975297513),
#  ('question', 0.014737821457209888),
#  ('of', 0.014700724309389193),
#  ('these', 0.0146807564208591),
#  ('evolution', 0.014677869382017863),
#  ('from', 0.014608837775710337),
#  ('after', 0.014347374675952878),
#  ('understand', 0.014310472943246702),
#  ('’', 0.01415787730503461),
#  ('physics', 0.013868599056526335),
#  ('trump', 0.013859825787798149),
#  ('first', 0.013820484010804912),
#  ('political', 0.013804532095093202),
#  ('natural', 0.013420837925274032),
#  ('new', 0.013086123427396176),
#  ('as', 0.012991981327004314),
#  ('evidence', 0.012914910358656077),
#  ('well', 0.01271735155267174),
#  ('national', 0.012689546123230635),
#  ('city', 0.012383999959198736),
#  ('society', 0.012264477605736603),
#  ('business', 0.01207577948262385),
#  ('any', 0.0120318929192968),
#  ('year-old', 0.011941467144738899),
#  ('since', 0.011889996809690759),
#  ('on', 0.011835942526332513),
#  ('has', 0.011831000526776457),
#  ('facts', 0.01148525473784473),
#  ('year', 0.011451048308439496),
#  ('race', 0.011353371698328635),
#  ('against', 0.01128756596301058),
#  ('sunday', 0.011076603232777977),
#  ('theory', 0.011066117448767234),
#  ('research', 0.010972056977779088),
#  ('large', 0.005963851814396455),
#  ('photos', 0.005962654817282165),
#  ('paris', 0.005961745424106518),
#  ('cannot', 0.005957439133181744),
#  ('democracy', 0.005941830544558475),
#  ('three', 0.005940156188622694),
#  ('march', 0.00592749106246447),
#  ('food', 0.0058985501036866615),
#  ('10', 0.005896936661241283),
#  ('out', 0.005893061859942913),
#  ('that', 0.005885355773679474),
#  ('members', 0.005881198275121803),
#  ('town', 0.00586738949086326),
#  ('states', 0.005840030477437097),
#  ('largest', 0.005838377960484452),
#  ('2018', 0.005811920225817942),
#  ('winston', 0.00580952963145259),
#  ('massive', 0.00579220756278999),
#  ('questions', 0.0057856443374756875),
#  ('two', 0.005784777052727546),
#  ('re', 0.005776706591253418),
#  ('rule', 0.005769855137730802),
#  ('nations', 0.0057660243067002995),
#  ('1', 0.005757823678854768),
#  ('claim', 0.005735281473548603),
#  ('almost', 0.005734947805527544),
#  ('community', 0.005728691047081096),
#  ('official', 0.005726326209420062),
#  ('film', 0.0057193107575165035),
#  ('clearly', 0.005717815112729499),
#  ('popular', 0.005715383823593193),
#  ('an', 0.005714140230339064),
#  ('protest', 0.00566881415496834),
#  ('both', 0.005667234926440748),
#  ('tower', 0.005662149556100029),
#  ('might', 0.0056538010151907505),
#  ('million', 0.005627736241665329),
#  ('hong', 0.005610944249310676),
#  ('fans', 0.005602815668608255),
#  ('mother', 0.005590453639970834),
#  ('island', 0.005583676714626019),
#  ('saturday', 0.005577575450658079),
#  ('asked', 0.005525376598785371),
#  ('french', 0.005523981408692649),
#  ('central', 0.005511222496771235),
#  ('culture', 0.005483957307137391),
#  ('voting', 0.005456461828337995),
#  ('merely', 0.005444679886928708),
#  ('streets', 0.0054331229160267626),
#  ('economic', 0.005432127408363636),
#  ('climate', 0.0054077917177994496),
#  ('forces', 0.005401739480478393),
#  ('data', 0.0053892756328143875),
#  ('based', 0.005386466780033308),
#  ('young', 0.005383610085305688),
#  ('global', 0.005382215806555777),
#  ('ignorance', 0.005379478290723183),
#  ('among', 0.005372981478965961),
#  ('interesting', 0.005362886111153926),
#  ('biology', 0.0053593456902472645),
#  ('appears', 0.005340699815046752),
#  ('election', 0.005319680519320347),
#  ('australia', 0.005313112586770349),
#  ("he's", 0.00530242392024692),
#  ('3', 0.005291549046489846),
#  ('quantum', 0.00528670135177838),
#  ('individuals', 0.005278783579625131),
#  ('a', 0.00527539940955069),
#  ('china', 0.005269356279574498),
#  ('complex', 0.005266813963252896),
#  ('systems', 0.005266338975694216),
#  ('now', 0.005262087334358263),
#  ('structure', 0.005261331948500413),
#  ('understanding', 0.005259705284758112),
#  ('idea', 0.005259272008171442),
#  ('were', 0.005256936472428551),
#  ('began', 0.005254969297983469),
#  ('february', 0.005247398203720837),
#  ('ceremony', 0.005240236192764571),
#  ('schools', 0.0052297256819553144),
#  ('los', 0.005197494334665683),
#  ('false', 0.005187342253550314),
#  ('talking', 0.005165793040143281),
#  ('whether', 0.005153335404287146),
#  ('proof', 0.005150741762360708),
#  ('increase', 0.005128192835549987),
#  ('humans', 0.005121076729980053),
#  ('issues', 0.002955585286770129),
#  ('behind', 0.002954964282447685),
#  ('sydney', 0.002954775798825233),
#  ('william', 0.0029498300054065355),
#  ('explained', 0.002948311234897064),
#  ('private', 0.0029391044078210574),
#  ('source', 0.0029382499655650433),
#  ('difficult', 0.0029319636416700163),
#  ('aid', 0.002931411402781639),
#  ('state', 0.002928580318681422),
#  ('frozen', 0.002926414222608518),
#  ('flint', 0.0029243990046794537),
#  ('tons', 0.002924158908074902),
#  ('19', 0.0029197798773312987),
#  ('taught', 0.002918380732024564),
#  ('fully', 0.002912189885290297),
#  ('europe', 0.0029121617644585515),
#  ('struck', 0.0029084019565037062),
#  ('languages', 0.002906683523283154),
#  ('front', 0.0029061831224616586),
#  ('colors', 0.002902254898302567),
#  ('evidences', 0.0029009626670061114),
#  ('holes', 0.0028992666091376975),
#  ('sea', 0.002899235741926128),
#  ('loss', 0.002896436322625803),
#  ('migrants', 0.002894870149315381),
#  ('arguments', 0.0028920656932288837),
#  ('beliefs', 0.002889093850029253),
#  ('dc', 0.002886776371618512),
#  ('debate', 0.002884762767822196),
#  ('second', 0.002884732299154986),
#  ('energy', 0.0028750680308949985),
#  ('motor', 0.002866981048693146),
#  ('destructive', 0.0028638711828722647),
#  ('covered', 0.002863101790685256),
#  ('duchess', 0.0028625805396886393),
#  ('billion', 0.0028598250867303897),
#  ('galaxy', 0.0028563578109578663),
#  ('catholic', 0.0028439534268107306),
#  ('variety', 0.002843226757046365),
#  ('shelter', 0.002841202452439425),
#  ('cells', 0.002840400046195319),
#  ("women's", 0.0028366475593189474),
#  ('career', 0.002834609414063154),
#  ('marking', 0.0028342424331335896),
#  ('clinton', 0.002833786459841746),
#  ('evolutionary', 0.0028334603568426157),
#  ('vice', 0.0028285256511063643),
#  ('without', 0.0028246833321817423),
#  ('entirely', 0.002823034523276399),
#  ('average', 0.0028197027913018416),
#  ('presidential', 0.0028126293981892933),
#  ('moral', 0.002808932931017568),
#  ('u', 0.002808846005351593),
#  ('driving', 0.0028076595568912186),
#  ('genes', 0.002807499456667105),
#  ('check', 0.0028031418716482084),
#  ('get', 0.0027979198443360206),
#  ('balance', 0.0027905549214425154),
#  ('wearing', 0.0027898786348066686),
#  ('rescue', 0.0027886077822598426),
#  ('africa', 0.0027871381286963615),
#  ('army', 0.0027835981568652872),
#  ('trouble', 0.0027825192914676016),
#  ('stuff', 0.002781567938529525),
#  ('flat', 0.002777477161871657),
#  ('distinction', 0.0027773118854957485),
#  ('conclusions', 0.0027766890538243163),
#  ('been', 0.002772532975052752),
#  ('absolute', 0.0027710090187583144),
#  ('100', 0.002762579662158906),
#  ('chimpanzees', 0.002761129665691451),
#  ('number', 0.002757028087026993),
#  ('moved', 0.002756970858365699),
#  ('material', 0.0027556386708544305),
#  ('requires', 0.0027484532735411356),
#  ('explanation', 0.0027478279707317662),
#  ('santa', 0.0027474571265641646),
#  ('celebrate', 0.002744720466261073),
#  ('via', 0.0027446507788343255),
#  ('89th', 0.00274198332961904),
#  ('category', 0.0027406550921487667),
#  ('whenever', 0.0027362171060829376),
#  ('eastern', 0.0027327298538166573),
#  ('highly', 0.0027282667912439783),
#  ('attempts', 0.0027273964864142253),
#  ('facebook', 0.002726645931870187),
#  ('it', 0.002725771425645186),
#  ('visible', 0.0027248010843658487),
#  ('logic', 0.0027206665111135313),
#  ('value', 0.0027153828412261696),
#  ('described', 0.002713930195716027),
#  ('statement', 0.0027127514047000575),
#  ('raise', 0.002712410854967825),
#  ('inevitably', 0.0027122028746704124),
#  ('statue', 0.0027094552243791567),
#  ('authorities', 0.0027083698986944877),
#  ('total', 0.0027083525100333058),
#  ('scientifically', 0.0027059642638769896),
#  ('wildfires', 0.0027019704091913728),
#  ('treatment', 0.0026999676752401014),
#  ('antarctic', 0.0026974875383483357),
#  ('son', 0.00268805781395191),
#  ('award', 0.0026852786978736175),
#  ('reasonable', 0.0026850204380572907),
#  ('comprehend', 0.0026832130043935236),
#  ('protests', 0.0026782702212391736),
#  ('institutions', 0.002672574878854284),
#  ('illuminated', 0.002671703082791811),
#  ('queen', 0.002668991082738373),
#  ('university', 0.002668018090967894),
#  ('fourth', 0.0026678747203518474),
#  ('results', 0.0026676030201241807),
#  ('spot', 0.0026643195614383048),
#  ('tempting', 0.002664153910768897),
#  ('objective', 0.002662868942791266),
#  ('studying', 0.002661484583715158),
#  ('rhetoric', 0.002661394197997256),
#  ('county', 0.0026602695842507184),
#  ('d', 0.002658670223780957),
#  ('throughout', 0.0026558016033894852),
#  ('designer', 0.002650805520605452),
#  ('classical', 0.0026493912724890596),
#  ('90', 0.002649317255890613),
#  ('irma', 0.0026409445095647616),
#  ('decades', 0.002640465600310863),
#  ('leads', 0.0026376193667241345),
#  ('reported', 0.0026368333936217774),
#  ('greece', 0.002635533027002213),
#  ('specific', 0.002635403275976755),
#  ('rare', 0.0026351215957452477),
#  ('inauguration', 0.0026347399036793467),
#  ('c', 0.0026343420275445075),
#  ('contemporary', 0.002633098014720185),
#  ('favorite', 0.002632310409528127),
#  ('combine', 0.0026322814151912167),
#  ('olympic', 0.0026293384283754256),
#  ('swipe', 0.0026291748184147905),
#  ('buy', 0.002626678926432525),
#  ('controversial', 0.0026216615963339214),
#  ('provide', 0.0026152805247321893),
#  ('lava', 0.0026138063679806162),
#  ('las', 0.0026122222334201556),
#  ('asking', 0.002611543512319231),
#  ('cheese', 0.0026105354547466906),
#  ('traditional', 0.0026069542704934075),
#  ('english', 0.0026060984391561193),
#  ('invented', 0.002601932676986933),
#  ('explains', 0.002601221022498929),
#  ('flooded', 0.0026007446434020576),
#  ('7', 0.0025995654347994936),
#  ('january', 0.0025979072071164026),
#  ('galaxies', 0.002591297153308251),
#  ('tour', 0.002586906066785942),
#  ('simple', 0.002583895520123332),
#  ('circumstantial', 0.002582281347685301),
#  ('majority', 0.002581914584486197),
#  ('pope', 0.0025813594242343123),
#  ('original', 0.0025783017938200976),
#  ('incredibly', 0.0025756188176576135),
#  ('survival', 0.002575203375116389),
#  ('fashion', 0.002572447628988351),
#  ('cuba', 0.0025712249399895324),
#  ("humanity's", 0.0025692832568836284),
#  ('pictured', 0.0025656235166489497),
#  ('carolina', 0.002560285888569335),
#  ('zoo', 0.0025598078694113397),
#  ('minute', 0.0025596200992014516),
#  ('floor', 0.0025573821717561995),
#  ('possibility', 0.002557077094255232),
#  ('opinion', 0.0025552845118277153),
#  ('pattern', 0.002555203595432538),
#  ('industry', 0.0025517968244999655),
#  ('motion', 0.0025493034273681592),
#  ('significant', 0.0025467948642992444),
#  ('seem', 0.002542304510370793),
#  ('projects', 0.0025407842101495257),
#  ('equal', 0.002539931901787075),
#  ('completely', 0.0025397920552744056),
#  ('despite', 0.002537449075945319),
#  ('led', 0.002537046325462662),
#  ('train', 0.002536073099744652),
#  ('locals', 0.002535174862505939),
#  ('fiber', 0.0025334771828150445),
#  ('effects', 0.0025332008244380966),
#  ('mask', 0.002531073221967305),
#  ('percent', 0.0025306551223932875),
#  ('philosophers', 0.0025287567760302557),
#  ('august', 0.0025272237835874587),
#  ('gut', 0.0025249932413095367),
#  ('interest', 0.00252097968398663),
#  ('april', 0.002519601845324838),
#  ('phrase', 0.0025190191040934725),
#  ('news', 0.002517071809144202),
#  ('amid', 0.0025159060588668598),
#  ('calories', 0.0025115414804849517),
#  ('indeed', 0.0025077291297996482),
#  ('earthquake', 0.0025032287871245345),
#  ('barack', 0.0025000787068133936),
#  ('classification', 0.002498364191268811),
#  ('cambridge', 0.002495385618376841),
#  ('origin', 0.002491027644260792),
#  ('reduce', 0.0024902562823381318),
#  ('terrorist', 0.002489964419369457),
#  ('proposed', 0.0024884479899148076),
#  ('earth', 0.002487335581377672),
#  ('houston', 0.0024865491368051516),
#  ('mechanism', 0.0024839684641225963),
#  ('received', 0.002483758487039632),
#  ('nasty', 0.0024799612102438143),
#  ("o'brien", 0.0024724772894199236),
#  ('27', 0.0024703335574207436),
#  ('dice', 0.002470050472980673),
#  ('sending', 0.002466971033522074),
#  ('ryan', 0.0024664710738146766),
#  ('efforts', 0.002466037538212646),
#  ('opposition', 0.0024606980039234864),
#  ('outer', 0.002455301039859076),
#  ('voters', 0.0024530272034067884),
#  ('sides', 0.0024517338210780686),
#  ('reasoning', 0.002451493281713095),
#  ('obviously', 0.002448582433432773),
#  ('christianity', 0.002446931741786841),
#  ('training', 0.0024452726459838247),
#  ('structures', 0.002444290518252102),
#  ('berlin', 0.002439540250567156),
#  ('children', 0.002436207332482803),
#  ('un', 0.0024345056268286654),
#  ('telescope', 0.002431733924667346),
#  ('position', 0.0024310102930580864),
#  ('driven', 0.002428566494398788),
#  ('illusion', 0.0024278962425786192),
#  ('displaced', 0.0024246609410907742),
#  ('virtual', 0.002422168149881039),
#  ('rock', 0.0024209997401372246),
#  ('multiculturalism', 0.0024191521236666034),
#  ('.', 0.002418914074074285),
#  ('dozens', 0.002416913860606271),
#  ('reads', 0.0024165715964777714),
#  ('officially', 0.00241532457185597),
#  ('demand', 0.0024149383746303378),
#  ('if', 0.002413735388877282),
#  ('gun', 0.0024135505423552145),
#  ('hunter', 0.0024127338334531886),
#  ('plays', 0.0024093356456407456),
#  ('alive', 0.00173721292552503),
#  ('but', 0.0017336586498431325),
#  ('started', 0.0017289302311453412),
#  ('creativity', 0.0017135484129603752),
#  ('look', 0.0017120037118369675),
#  ('distance', 0.0016998669430655271),
#  ('gets', 0.0016907884990025885),
#  ('jesus', 0.001687994854957765),
#  ('presence', 0.0016830401575508855),
#  ('keep', 0.0016691902655046054),
#  ('faith', 0.0016614732818790146),
#  ('broken', 0.0016549971159723698),
#  ('need', 0.0016455068617470636),
#  ('realize', 0.001641985963395927),
#  ('what', 0.0016285689557831444),
#  ('confidence', 0.0016253148825279662),
#  ('page', 0.0016203342419481065),
#  ('shines', 0.001616571134259585),
#  ('secret', 0.0016123188316799464),
#  ('envy', 0.0016099322208321545),
#  ('pride', 0.0016024838730331493),
#  ('stop', 0.0015976017125215827),
#  ('succeed', 0.0015914838754886565),
#  ('master', 0.0015767652603266202),
#  ('destination', 0.001575174143426511),
#  ('kept', 0.0015703601965749742),
#  ('ability', 0.0015683182623287613),
#  ('suffer', 0.0015680854269170697),
#  ('breathe', 0.0015544853755056188),
#  ('character', 0.0015481962925901543),
#  ('girl', 0.001534812179922705),
#  ('afraid', 0.0015301585489616934),
#  ('speaking', 0.0015262383423986928),
#  ('sleeping', 0.0015204087114452413),
#  ('lost', 0.0015199815661919504),
#  ('unique', 0.0015195684811626726),
#  ('sunshine', 0.0015180618966624858),
#  ('rest', 0.0015152175182006613),
#  ('sunset', 0.0015030876021826594),
#  ('friends', 0.0015008960139060914),
#  ('freedom', 0.0015008804599225807),
#  ('helps', 0.0014956292947556436),
#  ('stand', 0.0014885255988084632),
#  ('calm', 0.0014783672428065307),
#  ('angels', 0.001476651694153011),
#  ('possibilities', 0.001475145554635505),
#  ('memories', 0.0014749338786740162),
#  ('amazing', 0.0014718750192567048),
#  ('lived', 0.0014703248363648527),
#  ('pleasure', 0.0014695373500990443),
#  ('mistake', 0.001466436255302774),
#  ('discipline', 0.0014600617437035756),
#  ('luck', 0.001445180733825958),
#  ('blessed', 0.0014428506126362589),
#  ('responsibility', 0.0014427320781965256),
#  ('seeds', 0.0014424108056698738),
#  ('devil', 0.001439615789129339),
#  ('wake', 0.001435827847522689),
#  ('place', 0.0014345431575954412),
#  ('writer', 0.0014329900380562483),
#  ('growth', 0.001414807849112421),
#  ('upon', 0.0014117491544984077),
#  ('motivation', 0.0014093239282684093),
#  ('way', 0.0014080068517309243),
#  ('brave', 0.0014062334247935207),
#  ('wonderful', 0.0013931561738236271),
#  ('limit', 0.0013925082055907872),
#  ('rhythm', 0.001389010926911426),
#  ('fight', 0.0013875284964726003),
#  ('successful', 0.0013858175409145392),
#  ('goals', 0.0013839513882276005),
#  ('imagination', 0.001383816837551243),
#  ('us', 0.0013827180796436701),
#  ('small', 0.001378895719607952),
#  ('tears', 0.001375371370050298),
#  ('gratitude', 0.0013728736798138083),
#  ('drops', 0.001357414341231968),
#  ('rather', 0.0013564391511222058),
#  ('laughter', 0.0013545472976762743),
#  ('mountains', 0.0013529010403154412),
#  ('remember', 0.0013511884314938982),
#  ('walked', 0.0013416442639118608),
#  ('honest', 0.0013416143747208033),
#  ('giving', 0.0013406350412982072),
#  ('suffering', 0.001333576225140155),
#  ('blank', 0.0013223889966827171),
#  ('saw', 0.0013179181724630245),
#  ('choices', 0.0013129806093838175),
#  ('situation', 0.0013122185964510864),
#  ('grateful', 0.0013100620326925935),
#  ('goodness', 0.001307823140561505),
#  ('potential', 0.0013041399691847528),
#  ('blessings', 0.0013007484405090648),
#  ('nothing', 0.001299323265486195),
#  ('touch', 0.0012869462783755665),
#  ('bright', 0.0012868525487386264),
#  ('dwell', 0.0012839496060424427),
#  ('beginning', 0.0012783510019314067),
#  ('unexpected', 0.0012707588693495267),
#  ('breath', 0.0012628330882746177),
#  ('matters', 0.0012624000936247238),
#  ('hurt', 0.001256057259118165),
#  ('hide', 0.0012531186373208967),
#  ('sword', 0.0012527199261168093),
#  ('him', 0.0012465574226904405),
#  ('moving', 0.0012443496835799772),
#  ('fail', 0.001244262619938703),
#  ('heads', 0.001237111922651645),
#  ('fix', 0.0012361929039685646),
#  ('sacrifice', 0.0012342711673715382),
#  ('inspire', 0.0012276323801405098),
#  ('relationships', 0.0012264984190749827),
#  ('break', 0.001209558674285496),
#  ('becomes', 0.0012053824013850412),
#  ('wander', 0.0011986360010536117),
#  ('belong', 0.00119815114609408),
#  ('candle', 0.0011978545569427),
#  ('willing', 0.0011973186389442811),
#  ('loneliness', 0.00118866399474872),
#  ('misery', 0.0011866174953738587),
#  ('last', 0.0011861058211175605),
#  ('rain', 0.0011856927799356752),
#  ('relationship', 0.0011792870714341542),
#  ('obstacles', 0.0011776005572854131),
#  ('gray', 0.0011727074050766643),
#  ('having', 0.0011713448895623443),
#  ('sweet', 0.0011691637159830907),
#  ('talent', 0.0011680386292321106),
#  ('forgiveness', 0.0011678570111891596),
#  ('excellence', 0.0011672944354510677),
#  ('bring', 0.0011664731845998908),
#  ('...', 0.0011645956848807758),
#  ('direction', 0.0011619264566402005),
#  ('together', 0.0011575776583077207),
#  ('ideas', 0.0011568540861169217),
#  ('poet', 0.001151022720149387),
#  ('time', 0.0011489036829164597),
#  ('blooms', 0.0011457630779633595),
#  ('adventures', 0.0011433431546172632),
#  ('failures', 0.0011429000791195606),
#  ('anguish', 0.0011406630265380162),
#  ('whatever', 0.0011365761380026345),
#  ('plan', 0.001133686330782364),
#  ('eternity', 0.0011322522326223845),
#  ('unless', 0.0011266102065791849),
#  ("someone's", 0.0011233120243322068),
#  ('ends', 0.001118479902126779),
#  ('voices', 0.00111808087027516),
#  ('fire', 0.0011148154209064515),
#  ('flaws', 0.0011124683204898312),
#  ('places', 0.001106667781082766),
#  ('bad', 0.0011052534787796818),
#  ('achieving', 0.0011040675194726511),
#  ('takes', 0.0011010174520619876),
#  ('eternal', 0.0010988384541054063),
#  ('shallow', 0.0010984802953316643),
#  ('flow', 0.0010984551208145193),
#  ('till', 0.0010983410731464451),
#  ('flesh', 0.0010969571830472392),
#  ('chosen', 0.0010967658764105517),
#  ('worthy', 0.0010948749475847563),
#  ('sit', 0.001090217925415087),
#  ('feet', 0.0010899005893082747),
#  ('worrying', 0.001074888691083999),
#  ('mindfulness', 0.0010747784155006775),
#  ('teach', 0.00107343917047913),
#  ('instead', 0.0010730362630295787),
#  ('reward', 0.0010727326949445128),
#  ('road', 0.001071448887111866),
#  ('die', 0.0010702871773029764),
#  ('nights', 0.0010687131763892858),
#  ('helpless', 0.0010645087053992965),
#  ('sadness', 0.0010633457922834553),
#  ('trees', 0.0010598002129439208),
#  ('meditation', 0.0010590754518821073),
#  ('enthusiasm', 0.0010538026099206049),
#  ('darkest', 0.0010529600672866822),
#  ('choosing', 0.0010518732520615433),
#  ('roots', 0.0010514308356223074),
#  ('sat', 0.0010514099871681759),
#  ('done', 0.001050500944245916),
#  ('soft', 0.0010466321891186394),
#  ('foundation', 0.0010465848152563303),
#  ('builds', 0.0010451978342253352),
#  ('sun', 0.0010429439120799972),
#  ('changing', 0.0010386207341640183),
#  ('butterfly', 0.0010368480496204526),
#  ('voice', 0.0010304435996056137),
#  ('garden', 0.0010282386557536182),
#  ('miracles', 0.0010276196070797417),
#  ('glow', 0.0010253235927125677),
#  ('angel', 0.0010245830317412968),
#  ('losing', 0.0010218066296817196),
#  ('chooses', 0.0010194343276608518),
#  ('glad', 0.001019341630131212),
#  ('lord', 0.00101902969348501),
#  ('outward', 0.0010176017518093742),
#  ('nor', 0.0010160212305963669),
#  ('dying', 0.0010127729594285781),
#  ('follow', 0.0010118686143163343),
#  ('gifts', 0.0010095048288425985),
#  ('desire', 0.0010052768882294965),
#  ('home', 0.0010038678460686195),
#  ('one', 0.0010016663146526787),
#  ('encounter', 0.0009980198033299201),
#  ('settle', 0.0009971618107785301),
#  ("you'll", 0.000996842311943601),
#  ('okay', 0.0009948801657892609),
#  ('boredom', 0.0009941248946520927),
#  ('summer', 0.0009933900474311285),
#  ('whom', 0.000991680449807462),
#  ('favourite', 0.0009912999965133525),
#  ('dreamed', 0.0009875285372606176),
#  ('mindful', 0.0009873480376677336),
#  ('wishing', 0.0009851397209349958),
#  ('difficulties', 0.0009810593066635026),
#  ('maturity', 0.0009798351725762032),
#  ('purpose', 0.000979784240347424),
#  ('transformation', 0.0009711446636734414),
#  ('treasure', 0.0009681132690260696),
#  ('mistakes', 0.0009670568967372378),
#  ('marriage', 0.0009641935478383671),
#  ('praise', 0.0009607397270397748),
#  ('asceticism', 0.0009592443566497949),
#  ('throat', 0.0009583634163157952),
#  ('seek', 0.0009576174643986863),
#  ('despair', 0.000944337159646362),
#  ('fresh', 0.0009437531513144059),
#  ("god's", 0.0009409142091134056),
#  ('achieve', 0.0009374493263918978),
#  ("they've", 0.0009355703344615459),
#  ('promise', 0.0009309472986193348),
#  ('forgive', 0.0009303436061743603),
#  ('happens', 0.0009297064575752453),
#  ('weary', 0.0009290239412926305),
#  ('man', 0.0009278122565871214),
#  ('dirt', 0.0009268180626407624),
#  ('challenge', 0.0009218724418020069),
#  ('persons', 0.0009217136864501124),
#  ('closed', 0.0009212920259679135),
#  ('wash', 0.0009167662897157754),
#  ('seas', 0.0009156638015248975),
#  ('coffee', 0.0009129206789330884),
#  ("else's", 0.0009111045251254422),
#  ("didn't", 0.0009110528221559445),
#  ('pray', 0.0009040708593300138),
#  ('drawn', 0.0009025338348553407),
#  ('limitations', 0.0009017528037950221),
#  ('tranquillity', 0.0008967572217830268),
#  ('extraordinary', 0.0008964026225287801),
#  ('brilliant', 0.0008947714608413866),
#  ('stones', 0.0008926094207424726),
#  ('creative', 0.0008924605815043689),
#  ('gentle', 0.0008913888495037863),
#  ('authentic', 0.0008903466606139168),
#  ('stopped', 0.0008885423685229787),
#  ('overcome', 0.0008872321406308588),
#  ('destinies', 0.0008855641146962377),
#  ('cause', 0.0008832854435289531),
#  ('caring', 0.0008828759156029247),
#  ('stumble', 0.0008826281644808309),
#  ('tales', 0.0008826000137269357),
#  ('louder', 0.0008810978573518305),
#  ('waste', 0.0008779567829130455),
#  ('desert', 0.0008779336770169543),
#  ('the', 0.000876803566655104),
#  ('magical', 0.000876671765531994),
#  ('liked', 0.0008742346721825184),
#  ('otherwise', 0.0008741289667762547),
#  ('finds', 0.0008687217338190267),
#  ('endure', 0.00086770595534451),
#  ('roar', 0.0008635993379854594),
#  ('scars', 0.0008621804522916958),
#  ('dreaming', 0.0008611669084254713),
#  ('diamonds', 0.000858463474179537),
#  ('hurts', 0.0008582983227849438),
#  ('cared', 0.0008580706049535422),
#  ('goddess', 0.0008575756788217194),
#  ('hate', 0.0008536414656479526),
#  ('utter', 0.0008501019446258814),
#  ('seed', 0.0008493481383315913),
#  ('meaningful', 0.0008486089073685099),
#  ('feels', 0.0008481098236525675),
#  ('diamond', 0.0008455912166038794),
#  ('death', 0.0008455372218009365),
#  ('thread', 0.0008416975857346304),
#  ("people's", 0.0008409822464002397),
#  ('heal', 0.0008396770274236433),
#  ('determination', 0.0008391100094403631),
#  ('innocence', 0.0008383891168293112),
#  ('loves', 0.0008377612941676138),
#  ('wicked', 0.0008321181671768548),
#  ('courageous', 0.0008298500686545367),
#  ('brilliance', 0.0008253635438178243),
#  ('serenity', 0.000825304368144509),
#  ('friendships', 0.0008246433761719937),
#  ('longing', 0.000821742765370593),
#  ('feed', 0.0008215699502084533),
#  ('remain', 0.0008180443341703805),
#  ('spark', 0.0008158608796952552),
#  ('tragedy', 0.0008141808030593891),
#  ('weak', 0.0008118590040342136),
#  ('perception', 0.0008112166790468364),
#  ('quit', 0.0008107105187004102),
#  ('thousand', 0.0008094461691616159),
#  ('absence', 0.0008088427341033407),
#  ('risk', 0.0008080369254006208),
#  ('impact', 0.0008064216302280252),
#  ('usually', 0.0008060896158348551),
#  ('rich', 0.000804186896757582),
#  ('cling', 0.0008025577918981568),
#  ('pointing', 0.0008022690068790232),
#  ('steal', 0.0008001989695808904),
#  ('healed', 0.0007999623209833508),
#  ('worldly', 0.0007998161983402124),
#  ('deepest', 0.0007988306325877167),
#  ('storms', 0.0007982422179725671),
#  ('believe', 0.0007963181399333193),
#  ("she'd", 0.0007955770777317671),
#  ('another', 0.0007953227343015083),
#  ('soar', 0.0007949985917091342),
#  ('lovers', 0.0007941543359556252),
#  ('bow', 0.0007925959233542229),
#  ('muse', 0.0007916783797251767),
#  ('healing', 0.0007881727123370381),
#  ('lover', 0.0007876829196174793),
#  ('nothingness', 0.0007870636792721275),
#  ('idle', 0.0007843346782004461),
#  ('pen', 0.0007837958784296193),
#  ('naturally', 0.0007828782063832725),
#  ("would've", 0.0007827062144771689),
#  ('lazy', 0.0007815049575019147),
#  ('connected', 0.0007812685011760363),
#  ('ships', 0.0007804550769512609),
#  ('beginnings', 0.0007764804885324661),
#  ('thankful', 0.0007759087307369003),
#  ('land', 0.0007756153748463912),
#  ('matter', 0.0007754189911176028),
#  ('whispering', 0.0007730644061871061),
#  ('cool', 0.0007726544906254692),
#  ('aspire', 0.0007724226204087157),
#  ('seeing', 0.0007722017077888898),
#  ('stick', 0.0007714069756011955),
#  ('brings', 0.0007708122411732687),
#  ("shouldn't", 0.0007688850285501609),
#  ('hero', 0.0007685024076325849),
#  ('practice', 0.0007683192094687912),
#  ('dont', 0.0007667715578586863),
#  ('reflection', 0.0007662537985355065),
#  ('focused', 0.0007653828807119666),
#  ('blow', 0.000763267316525846),
#  ('habit', 0.0007620755816376235),
#  ('grief', 0.0007611790869701371),
#  ('threw', 0.0007599874976395289),
#  ('ten', 0.0007559744498795663),
#  ('yearn', 0.0007549135525352865),
#  ('walking', 0.0007530849625571339),
#  ('ruin', 0.000752177934957071),
#  ('hair', 0.0007521687855138728),
#  ('regrets', 0.000751947246227179),
#  ('looking', 0.0007499332468092099),
#  ('telling', 0.0007484407486935586),
#  ('bridges', 0.0007471198454734143),
#  ('cherish', 0.0007462685335471472),
#  ('distracted', 0.0007458484233058434),
#  ('spoken', 0.0007375099077418071),
#  ('noise', 0.0007356648132718558),
#  ('ear', 0.0007340860249640459),
#  ('wealth', 0.0007338213236813857),
#  ('wanna', 0.0007315285002304515),
#  ('drama', 0.0007289929761748628),
#  ('creates', 0.0007270047547611127),
#  ('thrill', 0.0007264494541296934),
#  ('capacity', 0.0007253799081115863),
#  ('fancy', 0.0007252519196905078),
#  ('strangers', 0.0007224301281517678),
#  ('poverty', 0.0007221083132825164),
#  ('pass', 0.0007201330249400117),
#  ('long', 0.0007171859997414038),
#  ('wonders', 0.0007168560898442171),
#  ('someday', 0.0007154178801548948),
#  ('tune', 0.0007142444599631806),
#  ('tomorrows', 0.0007135257223594924),
#  ('remaining', 0.0007119800839095012),
#  ('wounds', 0.0007119092273664022),
#  ('peaceful', 0.0007105124906118717),
#  ('right', 0.0007096197710483749),
#  ('individual', 0.0007090013703270532),
#  ('virtues', 0.0007072129715966766),
#  ('rainbows', 0.0007071383271672689),
#  ('taste', 0.0007071098968020834),
#  ('harmony', 0.0007069161488901574),
#  ('ears', 0.000706909086178727),
#  ('unconditional', 0.0007063082446773807),
#  ('elegance', 0.0007056150434574747),
#  ('pretty', 0.0007035116567251215),
#  ('mindset', 0.0007023842623125344),
#  ('handle', 0.0007007168364126718),
#  ('costs', 0.0006999259548759532),
#  ('jealous', 0.0006978314090741867),
#  ('mirror', 0.0006946613379082344),
#  ('spiritually', 0.0006941093422728414),
#  ('anyone', 0.0006940359233592504),
#  ('honesty', 0.0006939331293688562),
#  ('going', 0.0006929584434481337),
#  ('listening', 0.0006923572781749072),
#  ('goal', 0.0006908743398171347),
#  ('fulfilling', 0.0006899268073214262),
#  ('breeze', 0.0006887348152373469),
#  ('hug', 0.0006886883430995021),
#  ('anger', 0.000688593363289214),
#  ("person's", 0.0006880058423755425),
#  ('magic', 0.0006876507798283396),
#  ('given', 0.0006874207880921759),
#  ('letting', 0.0006865762945508906),
#  ('fortune', 0.0006851589140043554),
#  ('flame', 0.0006850913271249171),
#  ('regardless', 0.0006850627619987234),
#  ('excitement', 0.0006846920758325155),
#  ('heroic', 0.0006828546368269213),
#  ('easy', 0.0006827808155976243),
#  ('treasures', 0.0006816280024174345),
#  ('accomplish', 0.0006811749110917286),
#  ('motivated', 0.0006799370721189373),
#  ('lessons', 0.0006773573859107847),
#  ('clouds', 0.0006765031734816871),
#  ('goes', 0.0006749496182223987),
#  ('noble', 0.0006738382935557626),
#  ('inspires', 0.0006731499270142818),
#  ('comfortable', 0.0006722361496444236),
#  ('sweetest', 0.0006712696343585885),
#  ('quantity', 0.0006709479957110835),
#  ('ugly', 0.0006701371433526538),
#  ('fragrance', 0.000669791339647892),
#  ('tranquil', 0.0006694690529271044),
#  ('shore', 0.0006677805912983823),
#  ('toughest', 0.0006675286649580263),
#  ('nurse', 0.0006671180298460349),
#  ('platform', 0.0006667858698393129),
#  ('can', 0.0006664975566212),
#  ('challenges', 0.000665413797593941),
#  ('bitterness', 0.0006648566455644458),
#  ('bend', 0.0006636096589221312),
#  ('hell', 0.0006631850561076833),
#  ('whisper', 0.0006619023084251431),
#  ('hated', 0.000661643377845929),
#  ('struggle', 0.000661328522021983),
#  ('unhappiness', 0.0006585055813755637),
#  ('song', 0.0006583504127244259),
#  ('perfection', 0.0006564951164180154),
#  ('perseverance', 0.000655127576609967),
#  ('sway', 0.0006546334826575159),
#  ('miserable', 0.0006538021126949486),
#  ('warrior', 0.0006535784468522112),
#  ('rushing', 0.0006526120308216125),
#  ('uncomfortable', 0.000650499655771754),
#  ('zone', 0.0006504819246982054),
#  ('improvement', 0.0006499332400403272),
#  ('chest', 0.0006497542473480798),
#  ('nest', 0.0006493607012370214),
#  ('burdens', 0.0006491534967001805),
#  ('99', 0.0006482371107424893),
#  ('acting', 0.0006477691430024972),
#  ('required', 0.0006468453097127456),
#  ('hour', 0.0006466479658421871),
#  ('lamp', 0.0006459224952762237),
#  ('joyful', 0.0006451126558103997),
#  ('almighty', 0.0006443437444845668),
#  ('smell', 0.0006442605597862971),
#  ('crazy', 0.0006419370909525075),
#  ('whose', 0.0006418568572963946),
#  ('mixed', 0.0006416597375374534),
#  ('stone', 0.0006397439512147905),
#  ('figured', 0.000639078083131969),
#  ('stress', 0.00063558777848897),
#  ('atmosphere', 0.0006350160639889673),
#  ('weep', 0.0006341830654665206),
#  ('slaves', 0.0005218413558572851),
#  ('exquisite', 0.0005213430340553829),
#  ('funny', 0.0005203852926880106),
#  ('circumstance', 0.0005199915595560745),
#  ('worse', 0.0005190070280120786),
#  ('battle', 0.0005156267638170219),
#  ('─', 0.0005152018717867165),
#  ('smiled', 0.0005146578498510206),
#  ('stroke', 0.0005141562435653468),
#  ('spirits', 0.0005127417471229096),
#  ('uncertainty', 0.0005122307316733084),
#  ('reasons', 0.0005119852233945088),
#  ('decision', 0.0005114750206448058),
#  ('brighter', 0.0005109714823302883),
#  ('rays', 0.0005097187137448112),
#  ('spending', 0.0005092388566830434),
#  ('devils', 0.0005090278827808448),
#  ('effort', 0.0005076610260453592),
#  ('shadows', 0.0005068233376772178),
#  ('lucky', 0.0005064793652049832),
#  ('weird', 0.0005057638428304378),
#  ('run', 0.0005055664449953763),
#  ('birds', 0.0005044613875312819),
#  ('insignificant', 0.0005040522605221863),
#  ('meadows', 0.0005039000575266663),
#  ('awful', 0.0005035695110280473),
#  ('ship', 0.000503057567118709),
#  ('refusal', 0.0005025255122530324),
#  ('elevate', 0.000502379442304723),
#  ('dictate', 0.0005011073117557367),
#  ('shelf', 0.0005001934917078319),
#  ('intuition', 0.0004998159512506539),
#  ('determines', 0.0004990806975938317),
#  ('ending', 0.0004989076177123296),
#  ('brand', 0.0004983811223152646),
#  ('problems', 0.000498366459194137),
#  ('anxiety', 0.0004983496434347449),
#  ('smiles', 0.0004972139322815484),
#  ('ignite', 0.0004967850608424994),
#  ('achievement', 0.0004963698313557179),
#  ('top', 0.0004959700956949223),
#  ('fierce', 0.0004947880670166333),
#  ('revenge', 0.0004944633232940372),
#  ('roses', 0.0004933510713361791),
#  ('lifting', 0.0004930932644446267),
#  ('saving', 0.0004921628101773374),
#  ('hardest', 0.0004921395657258272),
#  ('midnight', 0.0004915508247735567),
#  ('weaknesses', 0.0004909712107356301),
#  ('blink', 0.0004907280422178703),
#  ('laughed', 0.0004898167475530474),
#  ('christian', 0.0004897600572616981),
#  ('virtue', 0.000488489099478476),
#  ('brightest', 0.0004881382014584885),
#  ('generous', 0.00048800631469071205),
#  ('halfway', 0.00048777534890137207),
#  ('thank', 0.00048726482015886585),
#  ('arrogance', 0.00048634027504445865),
#  ('bonds', 0.0004862368969963897),
#  ('make', 0.00048419968612855885),
#  ('somewhere', 0.00048380323184235666),
#  ('cold', 0.000482465545194447),
#  ('under', 0.00048110382748721924),
#  ('romance', 0.00048097840719542903),
#  ('entrepreneurs', 0.0004807916856593834),
#  ('affect', 0.0004806109110424144),
#  ('impress', 0.00048027226048947234),
#  ('fairy', 0.0004793291042444002),
#  ('strive', 0.0004775867679948197),
#  ('passions', 0.00047734686657449724),
#  ('library', 0.00047707594957290537),
#  ('rising', 0.0004769604941152193),
#  ('immeasurable', 0.0004751998618686058),
#  ('woman', 0.00047197289861635556),
#  ('inspiring', 0.00047171041183666066),
#  ('thrown', 0.0004715450072481802),
#  ('highs', 0.0004706182408589662),
#  ('self-denial', 0.0004705491337504901),
#  ('til', 0.0004704992268337786),
#  ('instrument', 0.0004703885053469393),
#  ('renaissance', 0.00047019145483861405),
#  ('riches', 0.0004700207618183095),
#  ('steady', 0.0004692193539450461),
#  ('forgiving', 0.0004690658965876297),
#  ('confronted', 0.0004689364182077369),
#  ('honey', 0.0004688544002015825),
#  ('rid', 0.000468134091410315),
#  ('deciding', 0.0004680360304167403),
#  ('sentient', 0.00046688876730012583),
#  ('angry', 0.0004662211543534786),
#  ('unnecessary', 0.00046490220787351555),
#  ('crafted', 0.0004642420964622122),
#  ('canvas', 0.0004639172930908938),
#  ('sing', 0.00046324076057045743),
#  ('stayed', 0.0004626226143412599),
#  ('expects', 0.00046215152600229446),
#  ('already', 0.0004615239824378247),
#  ('heals', 0.0004611798189225462),
#  ('anywhere', 0.00046091942447232844),
#  ('morally', 0.00046083418131653245),
#  ('recalling', 0.0004606946755463244),
#  ('wax', 0.0004602811851882121),
#  ('buried', 0.00046020021479750516),
#  ('willpower', 0.0004594748159036809),
#  ('void', 0.0004593172977187944),
#  ('inevitable', 0.0004592797229005985),
#  ('compelled', 0.0004587609524920159),
#  ("soul's", 0.00045857281340172887),
#  ('date', 0.00045699337804484726),
#  ('gigantic', 0.0004565555797264179),
#  ('adults', 0.00045631365673153766),
#  ('poor', 0.000456204355479527),
#  ('continuing', 0.00045568641652622276),
#  ('temptation', 0.00045561298833483405),
#  ('listened', 0.00045464639486604997),
#  ('seeks', 0.0004535424956414117),
#  ('engage', 0.00045306253551754514),
#  ('loses', 0.00045300146962194167),
#  ('mile', 0.00045028515190016457),
#  ('entertain', 0.00044971473469442106),
#  ('awake', 0.00044961473908087753),
#  ('radiant', 0.0004491878937200567),
#  ('ecstasy', 0.00044878918950727104),
#  ('harder', 0.0004485256963482832),
#  ('essence', 0.0004469174370587808),
#  ('appreciation', 0.00044678459136198),
#  ('high', 0.0004467674529559113),
#  ('ego', 0.00044658058910475144),
#  ("writer's", 0.00044593098287485505),
#  ('criterion', 0.0004455211433021383),
#  ('fulfill', 0.0004448030447364662),
#  ('possesses', 0.00044475343399412107),
#  ('lines', 0.0004446233675913228),
#  ('same', 0.0004444442517552651),
#  ("everyone's", 0.0004434795556142485),
#  ('vague', 0.00044332910558833),
#  ('dependent', 0.0004428996181908268),
#  ('substantial', 0.0004426374365145497),
#  ('combination', 0.00044221156046279794),
#  ('haunted', 0.00044195433300465954),
#  ('beloved', 0.00044173273698185333),
#  ('sin', 0.0004411449646496176),
#  ...]

# %% [markdown]
# ## t-SNE Visualization for the 300 most polarized words

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in mundane_vacuous_ratios.most_common(300):
    if(word in mlpfull.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(mundane_vacuous_ratios.most_common()))[0:300]:
    if(word in mlpfull.word2index.keys()):
        words_to_visualize.append(word)

# %%
mundane = 0
vacuous = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in mundane_vacuous_ratios.keys():
        vectors_list.append(mlpfull.weights_0_1[mlpfull.word2index[word]])
        if(mundane_vacuous_ratios[word] > 0):
            mundane+=1
            colors_list.append("#a8b821")
        else:
            vacuous+=1
            colors_list.append("#e16666")

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=5, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="10pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)
show(p)
